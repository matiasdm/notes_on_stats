# %% [markdown]
# # Development notebook. No experiments or results here. For dev purposes

# %%
run init.ipynb
# Out:
# Done.

# %% [markdown]
# # Experiment on the best imputation technics in the case of single disribution in the bayesian framework

# %%
"""  Fix parameters """

#Dataset default parameters
num_samples = NUM_SAMPLES

# pdf estimation default parameters
resolution = RESOLUTION
bandwidth = BANDWIDTH

# Classification default parameters
proportion_train = PROPORTION_TRAIN

# Verbosity
verbosity=0


"""  Parameters of the experiment """



range_dataset_name = ['circles', 'moons']
range_imputation_method = ['multi_dimensional_weighting', 'mice', 'knn', 'mean']

range_ratio_of_missing_values = [0., 0.25, 0.5]
range_ratio_missing_per_class = [[0,0.25], [0.1, 0.3]]
range_imbalance_ratio = [0.05, 0.25, 0.5]
range_missingness_pattern = [1, 2, 3, 4, 5]
approach = 'single_distribution'
missing_data_handling = 'imputation'


print("Approach is single distributions (bayesian framework) with imputations of the missing values!\n\n\n")
start_total_time = time()
for dataset_name in range_dataset_name:
    for imputation_method in range_imputation_method:
        for imbalance_ratio in range_imbalance_ratio:
            for missingness_pattern in range_missingness_pattern:
                
                if missingness_pattern in [1, 2, 3]:
                    for ratio_of_missing_values in range_ratio_of_missing_values:
                        
                        
                        try:
                            #if not len(df.query( " `dataset_name`==@dataset_name & `ratio_of_missing_values`==@ratio_of_missing_values & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :

                            print("{} - imputation method: {} imbalance: {} pattern: {} ratio :{}".format(dataset_name, 
                                                                                                          imputation_method, 
                                                                                                          imbalance_ratio,
                                                                                                          missingness_pattern,
                                                                                                          ratio_of_missing_values))

                            start_time = time()

                            dataset = DatasetGenerator(dataset_name=dataset_name, 
                                                    num_samples=num_samples, 
                                                    imbalance_ratio=imbalance_ratio, 
                                                    missing_data_handling=missing_data_handling,
                                                    imputation_method=imputation_method,
                                                    verbosity=verbosity)

                            # Creation of the missingness
                            dataset.generate_missing_coordinates(missingness_pattern=missingness_pattern, ratio_of_missing_values=ratio_of_missing_values, ratio_missing_per_class=None)

                            dataset.split_test_train()

                            # Create the experiments
                            exp = Experiments(dataset_name, 
                                              dataset=dataset, 
                                              purpose='classification', 
                                              approach = approach, 
                                              previous_experiment=None, 
                                              save_experiment=True, 
                                              verbosity=verbosity, 
                                              debug=False, 
                                              proportion_train=PROPORTION_TRAIN, 
                                              resolution=RESOLUTION, 
                                              bandwidth=BANDWIDTH,
                                              random_state=RANDOM_STATE)


                            # Estimate the distributions 
                            exp.fit()

                            # Estimate the distributions 
                            exp.predict()

                            # Plot results
                            #exp.plot()


                            end_time = time()

                            hours, rest = divmod(end_time - start_time, 3600)
                            minutes, seconds = divmod(rest, 60)
                            print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
                        except:
                            print("/!\. Error!\n")
                        
                elif missingness_pattern in [4, 5]:
                    for ratio_missing_per_class in range_ratio_missing_per_class:




                        try:
                            #if not len(df.query( " `dataset_name`==@dataset_name & `ratio_of_missing_values`==@ratio_of_missing_values & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :

                            print("{} - imputation method: {} imbalance: {} pattern: {} ratio per class: {}".format(dataset_name, 
                                                                                                                              imputation_method, 
                                                                                                                              imbalance_ratio,
                                                                                                                              missingness_pattern,
                                                                                                                              str(ratio_missing_per_class)))

                            start_time = time()

                            dataset = DatasetGenerator(dataset_name=dataset_name, 
                                                    num_samples=num_samples, 
                                                    imbalance_ratio=imbalance_ratio, 
                                                    missing_data_handling=missing_data_handling,
                                                    imputation_method=imputation_method,
                                                    verbosity=verbosity)

                            # Creation of the missingness
                            dataset.generate_missing_coordinates(missingness_pattern=missingness_pattern, ratio_of_missing_values=None, ratio_missing_per_class=ratio_missing_per_class)

                            dataset.split_test_train()

                            # Create the experiments
                            exp = Experiments(dataset_name, 
                                              dataset=dataset, 
                                              purpose='classification', 
                                              approach = approach, 
                                              previous_experiment=None, 
                                              save_experiment=True, 
                                              verbosity=verbosity, 
                                              debug=False, 
                                              proportion_train=PROPORTION_TRAIN, 
                                              resolution=RESOLUTION, 
                                              bandwidth=BANDWIDTH,
                                              random_state=RANDOM_STATE)


                            # Estimate the distributions 
                            exp.fit()

                            # Estimate the distributions 
                            exp.predict()

                            # Plot results
                            #exp.plot()


                            end_time = time()

                            hours, rest = divmod(end_time - start_time, 3600)
                            minutes, seconds = divmod(rest, 60)
                            print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
                        except:
                            print("/!\. Error!\n")

end_total_time = time()

hours, rest = divmod(end_total_time - start_total_time, 3600)
minutes, seconds = divmod(rest, 60)
print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
# Out:
# Approach is single distributions (bayesian framework) with imputations of the missing values!
#
#
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.05 pattern: 1 ratio :0.0
# Doing experiment 1!
# Done (0h 2m and 49.49s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.05 pattern: 1 ratio :0.25
# Doing experiment 2!
# Done (0h 3m and 25.55s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.05 pattern: 1 ratio :0.5
# Doing experiment 3!
# Done (0h 3m and 43.36s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.05 pattern: 2 ratio :0.0
# Doing experiment 4!
# Done (0h 2m and 54.41s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.05 pattern: 2 ratio :0.25
# Doing experiment 6!
# Done (0h 3m and 28.19s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.05 pattern: 2 ratio :0.5
# Doing experiment 7!
# Done (0h 3m and 26.58s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.05 pattern: 3 ratio :0.0
# Doing experiment 8!
# Done (0h 2m and 55.55s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.05 pattern: 3 ratio :0.25
# Doing experiment 9!
# Done (0h 3m and 29.99s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.05 pattern: 3 ratio :0.5
# Doing experiment 10!
# Done (0h 3m and 26.14s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.05 pattern: 4 ratio per class: [0, 0.25]
# Doing experiment 11!
# Done (0h 2m and 58.47s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.05 pattern: 4 ratio per class: [0.1, 0.3]
# Doing experiment 12!
# Done (0h 3m and 10.75s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.05 pattern: 5 ratio per class: [0, 0.25]
# Doing experiment 13!
# Done (0h 2m and 54.42s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.05 pattern: 5 ratio per class: [0.1, 0.3]
# Doing experiment 14!
# Done (0h 3m and 26.83s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio :0.0
# Doing experiment 15!
# Done (0h 2m and 55.10s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio :0.25
# Doing experiment 16!
# Done (0h 3m and 31.39s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio :0.5
# Doing experiment 17!
# Done (0h 3m and 45.52s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio :0.0
# Doing experiment 18!
# Done (0h 2m and 51.21s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio :0.25
# Doing experiment 19!
# Done (0h 3m and 29.63s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio :0.5
# Doing experiment 20!
# Done (0h 3m and 29.46s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio :0.0
# Doing experiment 21!
# Done (0h 2m and 50.04s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio :0.25
# Doing experiment 22!
# Done (0h 3m and 25.05s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio :0.5
# Doing experiment 23!
# Done (0h 3m and 26.36s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 4 ratio per class: [0, 0.25]
# Doing experiment 24!
# Done (0h 3m and 25.48s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 4 ratio per class: [0.1, 0.3]
# Doing experiment 25!
# Done (0h 3m and 9.10s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 5 ratio per class: [0, 0.25]
# Doing experiment 26!
# Done (0h 3m and 8.26s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 5 ratio per class: [0.1, 0.3]
# Doing experiment 27!
# Done (0h 3m and 29.57s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio :0.0
# Doing experiment 28!
# Done (0h 2m and 56.31s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio :0.25
# Doing experiment 29!
# Done (0h 3m and 35.79s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio :0.5
