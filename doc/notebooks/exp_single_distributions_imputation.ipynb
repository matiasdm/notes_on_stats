# %% [markdown]
# # Development notebook. No experiments or results here. For dev purposes

# %%
run init.ipynb
# Out:
# Done.

# %%
"""  Fix parameters """

#Dataset default parameters
num_samples = 8000#NUM_SAMPLES

# pdf estimation default parameters
resolution = RESOLUTION
bandwidth = BANDWIDTH

# Classification default parameters
proportion_train = PROPORTION_TRAIN

# Verbosity
verbosity=0


"""  Parameters of the experiment """



range_dataset_name = ['circles', 'moons']
range_imputation_method = ['multi_dimensional_weighting', 'mice', 'knn', 'mean']



range_ratio_of_missing_values = [0., 0.1, 0.2, 0.3]
range_ratio_missing_per_class = [[0, 0.25], [0.1, 0.3]]
range_imbalance_ratio = [0.1, 0.25, 0.5]
range_missingness_pattern = [1, 3, 4, 5]
approach = 'single_distribution'
missing_data_handling = 'imputation'

df = create_df()

print("Approach is single distributions (bayesian framework) with imputations of the missing values!\n\n\n")
start_total_time = time()
for dataset_name in range_dataset_name:
    for imputation_method in range_imputation_method:
        for imbalance_ratio in range_imbalance_ratio:
            for missingness_pattern in range_missingness_pattern:
                
                
                
                if missingness_pattern in [1, 2, 3]:
                    for ratio_of_missing_values in range_ratio_of_missing_values:
                        if len(df.query( " `dataset_name`==@dataset_name & `approach` == @approach & `imputation_method` == @imputation_method & `missing_data_handling` == @missing_data_handling & `ratio_of_missing_values`==@ratio_of_missing_values & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :
                            continue
                        
                        #try:
                        #if not len(df.query( " `dataset_name`==@dataset_name & `ratio_of_missing_values`==@ratio_of_missing_values & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :

                        print("{} - imputation method: {} imbalance: {} pattern: {} ratio :{}".format(dataset_name, 
                                                                                                      imputation_method, 
                                                                                                      imbalance_ratio,
                                                                                                      missingness_pattern,
                                                                                                      ratio_of_missing_values))

                        start_time = time()

                        dataset = DatasetGenerator(dataset_name=dataset_name, 
                                                num_samples=num_samples, 
                                                imbalance_ratio=imbalance_ratio, 
                                                missing_data_handling=missing_data_handling,
                                                imputation_method=imputation_method,
                                                verbosity=verbosity)

                        # Creation of the missingness
                        dataset.generate_missing_coordinates(missingness_pattern=missingness_pattern, ratio_of_missing_values=ratio_of_missing_values, ratio_missing_per_class=None)

                        dataset.split_test_train()

                        # Create the experiments
                        exp = Experiments(dataset_name, 
                                          dataset=dataset, 
                                          purpose='classification', 
                                          approach = approach, 
                                          previous_experiment=None, 
                                          save_experiment=True, 
                                          verbosity=verbosity, 
                                          debug=False, 
                                          proportion_train=PROPORTION_TRAIN, 
                                          resolution=RESOLUTION, 
                                          bandwidth=BANDWIDTH,
                                          random_state=RANDOM_STATE)


                        # Estimate the distributions 
                        exp.fit()

                        # Estimate the distributions 
                        exp.predict()

                        # Plot results
                        #exp.plot()


                        end_time = time()

                        hours, rest = divmod(end_time - start_time, 3600)
                        minutes, seconds = divmod(rest, 60)
                        print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
                        #except:
                        #    print("/!\. Error!\n")
                        
                elif missingness_pattern in [4, 5]:
                    for ratio_missing_per_class in range_ratio_missing_per_class:
                        if len(df.query( " `dataset_name`==@dataset_name & `approach` == @approach & `imputation_method` == @imputation_method & `missing_data_handling` == @missing_data_handling & `ratio_missing_per_class_0`==@ratio_missing_per_class[0] & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :
                            continue




                        #try:
                            #if not len(df.query( " `dataset_name`==@dataset_name & `ratio_of_missing_values`==@ratio_of_missing_values & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :

                        print("{} - imputation method: {} imbalance: {} pattern: {} ratio per class: {}".format(dataset_name, 
                                                                                                                          imputation_method, 
                                                                                                                          imbalance_ratio,
                                                                                                                          missingness_pattern,
                                                                                                                          str(ratio_missing_per_class)))

                        start_time = time()

                        dataset = DatasetGenerator(dataset_name=dataset_name, 
                                                num_samples=num_samples, 
                                                imbalance_ratio=imbalance_ratio, 
                                                missing_data_handling=missing_data_handling,
                                                imputation_method=imputation_method,
                                                verbosity=verbosity)

                        # Creation of the missingness
                        dataset.generate_missing_coordinates(missingness_pattern=missingness_pattern, ratio_of_missing_values=None, ratio_missing_per_class=ratio_missing_per_class)

                        dataset.split_test_train()

                        # Create the experiments
                        exp = Experiments(dataset_name, 
                                          dataset=dataset, 
                                          purpose='classification', 
                                          approach = approach, 
                                          previous_experiment=None, 
                                          save_experiment=True, 
                                          verbosity=verbosity, 
                                          debug=False, 
                                          proportion_train=PROPORTION_TRAIN, 
                                          resolution=RESOLUTION, 
                                          bandwidth=BANDWIDTH,
                                          random_state=RANDOM_STATE)


                        # Estimate the distributions 
                        exp.fit()

                        # Estimate the distributions 
                        exp.predict()

                        # Plot results
                        #exp.plot()


                        end_time = time()

                        hours, rest = divmod(end_time - start_time, 3600)
                        minutes, seconds = divmod(rest, 60)
                        print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
                        #except:
                        #    print("/!\. Error!\n")

end_total_time = time()

hours, rest = divmod(end_total_time - start_total_time, 3600)
minutes, seconds = divmod(rest, 60)
print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
# Out:
# Approach is single distributions (bayesian framework) with imputations of the missing values!
#
#
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.1 pattern: 4 ratio per class: [0.1, 0.3]
# Doing experiment 28!
# Done (0h 11m and 18.28s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.1 pattern: 5 ratio per class: [0, 0.25]
# Doing experiment 29!
# Done (0h 14m and 22.71s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.1 pattern: 5 ratio per class: [0.1, 0.3]
# Doing experiment 30!
# Done (0h 12m and 32.34s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio :0.0
# Doing experiment 31!
# Done (0h 14m and 50.22s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio :0.1
# Doing experiment 32!
# Done (0h 13m and 49.10s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio :0.2
# Doing experiment 33!
# Done (0h 15m and 20.10s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio :0.3
# Doing experiment 34!
# Done (0h 18m and 20.63s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio :0.0
# Doing experiment 35!
# Done (0h 13m and 22.41s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio :0.1
# Doing experiment 36!
# Done (0h 13m and 11.00s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio :0.2
# Doing experiment 37!
# Done (0h 14m and 51.12s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio :0.3
# Doing experiment 38!
# Done (0h 7m and 45.87s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 4 ratio per class: [0, 0.25]
# Doing experiment 39!
# Done (0h 5m and 55.21s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 4 ratio per class: [0.1, 0.3]
# Doing experiment 40!
# Done (0h 5m and 16.97s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 5 ratio per class: [0, 0.25]
# Doing experiment 41!
# Done (0h 5m and 7.57s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.25 pattern: 5 ratio per class: [0.1, 0.3]
# Doing experiment 42!
# Done (0h 4m and 55.58s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio :0.0
# Doing experiment 43!
# Done (0h 4m and 29.92s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio :0.1
# Doing experiment 44!
# Done (0h 5m and 19.09s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio :0.2
# Doing experiment 45!
# Done (0h 5m and 52.90s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio :0.3
# Doing experiment 46!
# Done (0h 6m and 19.07s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio :0.0
# Doing experiment 47!
# Done (0h 4m and 30.07s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio :0.1
# Doing experiment 48!
# Done (0h 5m and 16.57s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio :0.2
# Doing experiment 49!
# Done (0h 5m and 51.70s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio :0.3
# Doing experiment 50!
# Done (0h 6m and 19.18s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.5 pattern: 4 ratio per class: [0, 0.25]
# Doing experiment 51!
# Done (0h 6m and 27.02s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.5 pattern: 4 ratio per class: [0.1, 0.3]
# Doing experiment 52!
# Done (0h 4m and 57.94s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.5 pattern: 5 ratio per class: [0, 0.25]
# Doing experiment 53!
# Done (0h 5m and 19.73s).
#
# circles - imputation method: multi_dimensional_weighting imbalance: 0.5 pattern: 5 ratio per class: [0.1, 0.3]
# Doing experiment 54!
# Done (0h 5m and 20.06s).
#
# circles - imputation method: mice imbalance: 0.1 pattern: 1 ratio :0.0
# Doing experiment 55!
# Done (0h 4m and 27.30s).
#
# circles - imputation method: mice imbalance: 0.1 pattern: 1 ratio :0.1
# Doing experiment 56!
# Done (0h 4m and 27.04s).
#
# circles - imputation method: mice imbalance: 0.1 pattern: 1 ratio :0.2
# Doing experiment 57!
# Done (0h 4m and 27.72s).
#
# circles - imputation method: mice imbalance: 0.1 pattern: 1 ratio :0.3
# Doing experiment 58!
# Done (0h 4m and 27.35s).
#
# circles - imputation method: mice imbalance: 0.1 pattern: 3 ratio :0.0
# Doing experiment 59!
# Done (0h 4m and 34.47s).
#
# circles - imputation method: mice imbalance: 0.1 pattern: 3 ratio :0.1
# Doing experiment 60!
# Done (0h 4m and 33.38s).
#
# circles - imputation method: mice imbalance: 0.1 pattern: 3 ratio :0.2
# Doing experiment 61!
# Done (0h 4m and 40.03s).
#
# circles - imputation method: mice imbalance: 0.1 pattern: 3 ratio :0.3
# Doing experiment 62!
# Done (0h 4m and 35.10s).
#
# circles - imputation method: mice imbalance: 0.1 pattern: 4 ratio per class: [0, 0.25]
# Doing experiment 63!
# Done (0h 4m and 31.56s).
#
# circles - imputation method: mice imbalance: 0.1 pattern: 4 ratio per class: [0.1, 0.3]
# Doing experiment 64!
# Done (0h 4m and 41.93s).
#
# circles - imputation method: mice imbalance: 0.1 pattern: 5 ratio per class: [0, 0.25]
# Doing experiment 65!
# Done (0h 4m and 36.61s).
#
# circles - imputation method: mice imbalance: 0.1 pattern: 5 ratio per class: [0.1, 0.3]
# Doing experiment 66!
# Done (0h 4m and 35.14s).
#
# circles - imputation method: mice imbalance: 0.25 pattern: 1 ratio :0.0
# Doing experiment 67!
# Done (0h 4m and 34.44s).
#
# circles - imputation method: mice imbalance: 0.25 pattern: 1 ratio :0.1
# Doing experiment 68!
# Done (0h 4m and 37.10s).
#
# circles - imputation method: mice imbalance: 0.25 pattern: 1 ratio :0.2
# Doing experiment 69!
# Done (0h 4m and 38.11s).
#
# circles - imputation method: mice imbalance: 0.25 pattern: 1 ratio :0.3
# Doing experiment 70!
# Done (0h 4m and 43.69s).
#
# circles - imputation method: mice imbalance: 0.25 pattern: 3 ratio :0.0
# Doing experiment 71!
# Done (0h 4m and 36.38s).
#
# circles - imputation method: mice imbalance: 0.25 pattern: 3 ratio :0.1
# Doing experiment 72!
# Done (0h 4m and 33.98s).
#
# circles - imputation method: mice imbalance: 0.25 pattern: 3 ratio :0.2
# Doing experiment 73!
# Done (0h 4m and 29.06s).
#
# circles - imputation method: mice imbalance: 0.25 pattern: 3 ratio :0.3
# Doing experiment 74!
# Done (0h 4m and 29.62s).
#
# circles - imputation method: mice imbalance: 0.25 pattern: 4 ratio per class: [0, 0.25]
# Doing experiment 75!
# Done (0h 4m and 30.14s).
#
# circles - imputation method: mice imbalance: 0.25 pattern: 4 ratio per class: [0.1, 0.3]
# Doing experiment 76!
# Done (0h 10m and 9.17s).
#
# circles - imputation method: mice imbalance: 0.25 pattern: 5 ratio per class: [0, 0.25]
# Doing experiment 80!
# Done (0h 15m and 45.76s).
#
# circles - imputation method: mice imbalance: 0.25 pattern: 5 ratio per class: [0.1, 0.3]
# Doing experiment 88!
# Done (0h 13m and 44.95s).
#
# circles - imputation method: mice imbalance: 0.5 pattern: 1 ratio :0.0
# Doing experiment 95!
# Done (0h 12m and 36.68s).
#
# circles - imputation method: mice imbalance: 0.5 pattern: 1 ratio :0.1
# Doing experiment 102!
# Done (0h 12m and 47.26s).
#
# circles - imputation method: mice imbalance: 0.5 pattern: 1 ratio :0.2
# Doing experiment 108!
# Done (0h 12m and 48.80s).
#
# circles - imputation method: mice imbalance: 0.5 pattern: 1 ratio :0.3
# Doing experiment 114!
# Done (0h 13m and 9.81s).
#
# circles - imputation method: mice imbalance: 0.5 pattern: 3 ratio :0.0
# Doing experiment 121!
# Done (0h 13m and 0.95s).
#
# circles - imputation method: mice imbalance: 0.5 pattern: 3 ratio :0.1
# Doing experiment 128!
# Done (0h 13m and 16.77s).
#
# circles - imputation method: mice imbalance: 0.5 pattern: 3 ratio :0.2
# Doing experiment 135!
# Done (0h 12m and 45.58s).
#
# circles - imputation method: mice imbalance: 0.5 pattern: 3 ratio :0.3
# Doing experiment 141!
# Done (0h 13m and 16.60s).
#
# circles - imputation method: mice imbalance: 0.5 pattern: 4 ratio per class: [0, 0.25]
# Doing experiment 143!
# Done (0h 14m and 48.63s).
#
# circles - imputation method: mice imbalance: 0.5 pattern: 4 ratio per class: [0.1, 0.3]
# Doing experiment 145!
# Done (0h 13m and 36.25s).
#
# circles - imputation method: mice imbalance: 0.5 pattern: 5 ratio per class: [0, 0.25]
# Doing experiment 146!
# Done (0h 14m and 26.14s).
#
# circles - imputation method: mice imbalance: 0.5 pattern: 5 ratio per class: [0.1, 0.3]
# Doing experiment 148!
# Done (0h 12m and 36.84s).
#
# circles - imputation method: knn imbalance: 0.1 pattern: 1 ratio :0.0
# Doing experiment 150!
# Done (0h 14m and 26.18s).
#
# circles - imputation method: knn imbalance: 0.1 pattern: 1 ratio :0.1
# Doing experiment 152!
# Done (0h 12m and 23.77s).
#
# circles - imputation method: knn imbalance: 0.1 pattern: 1 ratio :0.2
# Doing experiment 153!
# Done (0h 12m and 55.70s).
#
# circles - imputation method: knn imbalance: 0.1 pattern: 1 ratio :0.3
# Doing experiment 155!
# Done (0h 13m and 19.74s).
#
# circles - imputation method: knn imbalance: 0.1 pattern: 3 ratio :0.0
# Doing experiment 157!
# Done (0h 5m and 12.95s).
#
# circles - imputation method: knn imbalance: 0.1 pattern: 3 ratio :0.1
# Doing experiment 159!
# Done (0h 4m and 33.55s).
#
# circles - imputation method: knn imbalance: 0.1 pattern: 3 ratio :0.2
# Doing experiment 161!
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-5a0f561ed9ee> in <module>
#      89
#      90                         # Estimate the distributions
# ---> 91                         exp.predict()
#      92
#      93                         # Plot results
#
# ~/Duke/work/notes_on_stats/doc/src/experiments.py in predict(self)
#     163
#     164         if self.save_experiment:
# --> 165             self.save()
#     166
#     167         return
#
# ~/Duke/work/notes_on_stats/doc/src/experiments.py in save(self)
#     456
#     457             #-------- Save Distributions ----------#
# --> 458             self.dist_pos.save(experiment_path=self.experiment_path)
#     459             self.dist_neg.save(experiment_path=self.experiment_path)
#     460
#
# ~/Duke/work/notes_on_stats/doc/src/model/bayesian/distributions.py in save(self, experiment_path)
#     235         #-------- Save dataset ----------#
#     236         with open(os.path.join(experiment_path, 'distributions_{}_log.json'.format(self.class_used)), 'w') as outfile:
# --> 237             json.dump(self, outfile, default=lambda o: o.astype(float) if type(o) == np.int64 else o.tolist() if type(o) == np.ndarray else o.to_json(orient='records') if type(o) == pd.core.frame.DataFrame else o.__dict__)
#     238
#     239     def load(self, dataset_data):
#
# ~/anaconda3/envs/combinations/lib/python3.7/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     178     # a debuggability cost
#     179     for chunk in iterable:
# --> 180         fp.write(chunk)
#     181
#     182
#
# OSError: [Errno 28] No space left on device
