# %% [markdown]
# # Experiment on the encoding and imputing technics for the Nam network, with and without Z !

# %%
run init.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Done.

# %% [markdown]
# **`NAN` Second set of experiments deciding wheether `using indicator variable is useful`**

# %%
"""  Parameters of the experiment """
approach = 'DecisionTree'

range_dataset_name = ['circles', 'moons', 'blobs']
range_ratio_of_missing_values = [0., 0.1, 0.2, 0.3]
range_ratio_missing_per_class = [[0,0.25], [0.1, 0.3]]
range_imbalance_ratio = [0.5, 0.25, 0.1]
range_missingness_pattern = [1, 3, 4, 5]

range_missing_data_handling = ['encoding', 'imputation'] #TODO THIS IS WHERE WE SHOULD DO IMUTING BASED ON THE  OTHER EXPERIMENT
imputation_method = 'multi_dimensional_weighting'
range_use_missing_indicator_variables = [False, True]

# %%
#df = create_df(folder_names=['experiments_29_june_duke'])
#df = df.append(pd.read_csv("/home01/sam/df_all_experiments.csv"))


df = pd.read_csv("/home01/sam/notes_on_stats/doc/src/data/experiemnt_8.csv")

df['ratio_missing_per_class_0'] = df['ratio_missing_per_class_0'].astype(float).round(2)
df['ratio_missing_per_class_1'] = df['ratio_missing_per_class_1'].astype(float).round(2)
df['ratio_of_missing_values'] = df['ratio_of_missing_values'].astype(float).round(2)
df
# Out:
#     dataset_name  experiment_number      approach missing_data_handling imputation_method  use_missing_indicator_variables  num_samples  imbalance_ratio  missingness_pattern missingness_mechanism  ratio_of_missing_values  missing_X1  missing_X2 missing_first_quarter  ratio_missing_per_class_0  ratio_missing_per_class_1  auc  Accuracy     F1    MCC  Sensitivity  Specificity  Precision    PPV    NPV    FNR    FDR    FOR  resolution  bandwidth  estimation_time_0  estimation_time_1
# 0        circles                333  DecisionTree              encoding           without                            False         5000              0.5                    1                  MCAR                      0.0        True       False                   NaN                        NaN                        NaN  NaN     0.835  0.851  0.690        0.952        0.720      0.770  0.770  0.938  0.048  0.230  0.062          20        0.2                NaN                NaN
# 1        circles                334  DecisionTree              encoding           without                            False         5000              0.5                    1                  MCAR                      0.1        True       False                   NaN                        NaN                        NaN  NaN     0.819  0.843  0.654        0.940        0.689      0.765  0.765  0.915  0.060  0.235  0.085          20        0.2                NaN                NaN
# 2        circles                336  DecisionTree              encoding           without                            False         5000              0.5                    1                  MCAR                      0.2        True       False                   NaN                        NaN                        NaN  NaN     0.813  0.834  0.656        0.957        0.673      0.739  0.739  0.942  0.043  0.261  0.058          20        0.2                NaN                NaN
# 3        circles                338  DecisionTree              encoding           without                            False         5000              0.5                    1                  MCAR                      0.3        True       False                   NaN                        NaN                        NaN  NaN     0.793  0.814  0.624        0.952        0.649      0.711  0.711  0.937  0.048  0.289  0.063          20        0.2                NaN                NaN
# 4        circles                339  DecisionTree              encoding           without                            False         5000              0.5                    2                   MAR                      0.0        True        True                  True                        NaN                        NaN  NaN     0.835  0.851  0.690        0.952        0.720      0.770  0.770  0.938  0.048  0.230  0.062          20        0.2                NaN                NaN
# ..           ...                ...           ...                   ...               ...                              ...          ...              ...                  ...                   ...                      ...         ...         ...                   ...                        ...                        ...  ...       ...    ...    ...          ...          ...        ...    ...    ...    ...    ...    ...         ...        ...                ...                ...
# 247        blobs                590  DecisionTree              encoding           without                             True         5000              0.1                    3                   MAR                      0.3        True       False                  True                        NaN                        NaN  NaN     0.963  0.804  0.804        0.673        1.000      1.000  1.000  0.960  0.327  0.000  0.040          20        0.2                NaN                NaN
# 248        blobs                591  DecisionTree              encoding           without                             True         5000              0.1                    4                  MNAR                      NaN        True        True                 False                        0.0                       0.25  NaN     0.990  0.952  0.947        0.952        0.994      0.952  0.952  0.994  0.048  0.048  0.006          20        0.2                NaN                NaN
# 249        blobs                592  DecisionTree              encoding           without                             True         5000              0.1                    4                  MNAR                      NaN        True        True                 False                        0.1                       0.30  NaN     0.957  0.775  0.758        0.692        0.989      0.881  0.881  0.964  0.308  0.119  0.036          20        0.2                NaN                NaN
# 250        blobs                593  DecisionTree              encoding           without                             True         5000              0.1                    5                  MNAR                      NaN        True        True                  True                        0.0                       0.25  NaN     0.992  0.952  0.948        0.941        0.997      0.964  0.964  0.995  0.059  0.036  0.005          20        0.2                NaN                NaN
# 251        blobs                594  DecisionTree              encoding           without                             True         5000              0.1                    5                  MNAR                      NaN        True        True                  True                        0.1                       0.30  NaN     0.960  0.800  0.778        0.816        0.976      0.784  0.784  0.980  0.184  0.216  0.020          20        0.2                NaN                NaN
#
# [252 rows x 32 columns]

# %%
"""  Fix parameters """
#Dataset default parameters
num_samples = NUM_SAMPLES

# pdf estimation default parameters
resolution = RESOLUTION
bandwidth = BANDWIDTH

# Classification default parameters
proportion_train = PROPORTION_TRAIN

# Verbosity
verbosity=0

save=True

missingness_dictionnary = {1: (range_ratio_of_missing_values, len(range_ratio_of_missing_values)*[None]),
                           2: (range_ratio_of_missing_values, len(range_ratio_of_missing_values)*[None]),
                           3: (range_ratio_of_missing_values, len(range_ratio_of_missing_values)*[None]),
                           4: (len(range_ratio_missing_per_class)*[None], range_ratio_missing_per_class),
                           5: (len(range_ratio_missing_per_class)*[None], range_ratio_missing_per_class)}


for use_missing_indicator_variables in range_use_missing_indicator_variables:
    
    for imbalance_ratio in range_imbalance_ratio:
        
        
        for missing_data_handling in range_missing_data_handling:


            for dataset_name in range_dataset_name:


                for missingness_pattern, (ratio_of_missing_values_list, ratio_missing_per_class_list) in missingness_dictionnary.items():

                    for ratio_of_missing_values, ratio_missing_per_class in zip(ratio_of_missing_values_list, ratio_missing_per_class_list):





                        if check_experiment_already_done(df, 
                                                          dataset_name=dataset_name, 
                                                          approach=approach,
                                                          imbalance_ratio=imbalance_ratio, 
                                                          missingness_pattern=missingness_pattern, 
                                                          imputation_method=imputation_method,
                                                          missing_data_handling=missing_data_handling, 
                                                          use_missing_indicator_variables=use_missing_indicator_variables,
                                                          ratio_of_missing_values=ratio_of_missing_values, 
                                                          ratio_missing_per_class_0=ratio_missing_per_class[0] if ratio_missing_per_class is not None else None):


                            print("Experiment already done.")
                            continue
                        if (dataset_name == 'moons' and missingness_pattern in [3, 5]) or (range_ratio_of_missing_values==0 and missingness_pattern != 1) or (missing_data_handling in ['without', 'encoding'] and imputation_method!=None):
                            print("Not doing this.")
                            continue
                            
                            
                            
                        print("{} - imputation method: {} missing_data_handling: {} imbalance: {} pattern: {} ratio_missing:{} ratio_per_class: {}".format(dataset_name, 
                                                                                                                                                        missing_data_handling,
                                                                                                                                                          imputation_method, 
                                                                                                                                                          imbalance_ratio,
                                                                                                                                                          missingness_pattern,
                                                                                                                                                          ratio_of_missing_values, 
                                                                                                                                                              ratio_missing_per_class))
                        
                        #while True:
                        #    pass
# Out:
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio_missing:0.0 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio_missing:0.1 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Not doing this.
# Not doing this.
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio_missing:0.0 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio_missing:0.1 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio_missing:0.0 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio_missing:0.1 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Not doing this.
# Not doing this.
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio_missing:0.0 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio_missing:0.1 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 3 ratio_missing:0.0 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 3 ratio_missing:0.1 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Not doing this.
# Not doing this.
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 3 ratio_missing:0.0 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 3 ratio_missing:0.1 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio_missing:0.0 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio_missing:0.1 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Not doing this.
# Not doing this.
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio_missing:0.0 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio_missing:0.1 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio_missing:0.0 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio_missing:0.1 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Not doing this.
# Not doing this.
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio_missing:0.0 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio_missing:0.1 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 3 ratio_missing:0.0 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 3 ratio_missing:0.1 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Not doing this.
# Not doing this.
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 3 ratio_missing:0.0 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 3 ratio_missing:0.1 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]

# %%
"""  Fix parameters """
#Dataset default parameters
num_samples = NUM_SAMPLES

# pdf estimation default parameters
resolution = RESOLUTION
bandwidth = BANDWIDTH

# Classification default parameters
proportion_train = PROPORTION_TRAIN

# Verbosity
verbosity=0

save=True

missingness_dictionnary = {1: (range_ratio_of_missing_values, len(range_ratio_of_missing_values)*[None]),
                           2: (range_ratio_of_missing_values, len(range_ratio_of_missing_values)*[None]),
                           3: (range_ratio_of_missing_values, len(range_ratio_of_missing_values)*[None]),
                           4: (len(range_ratio_missing_per_class)*[None], range_ratio_missing_per_class),
                           5: (len(range_ratio_missing_per_class)*[None], range_ratio_missing_per_class)}


for use_missing_indicator_variables in range_use_missing_indicator_variables:
    
    for imbalance_ratio in range_imbalance_ratio:
        
        
        for missing_data_handling in range_missing_data_handling:


            for dataset_name in range_dataset_name:


                for missingness_pattern, (ratio_of_missing_values_list, ratio_missing_per_class_list) in missingness_dictionnary.items():

                    for ratio_of_missing_values, ratio_missing_per_class in zip(ratio_of_missing_values_list, ratio_missing_per_class_list):





                        if check_experiment_already_done(df, 
                                                          dataset_name=dataset_name, 
                                                          approach=approach,
                                                          imbalance_ratio=imbalance_ratio, 
                                                          missingness_pattern=missingness_pattern, 
                                                          imputation_method=imputation_method,
                                                          missing_data_handling=missing_data_handling, 
                                                          use_missing_indicator_variables=use_missing_indicator_variables,
                                                          ratio_of_missing_values=ratio_of_missing_values, 
                                                          ratio_missing_per_class_0=ratio_missing_per_class[0] if ratio_missing_per_class is not None else None):


                            print("Experiment already done.")
                            continue
                        if (dataset_name == 'moons' and missingness_pattern in [3, 5]) or (range_ratio_of_missing_values==0 and missingness_pattern != 1) or (missing_data_handling in ['without', 'encoding'] and imputation_method!=None):
                            print("Not doing this.")
                            continue
                            
                            
                            
                        print("{} - {} - missing_data_handling {} imputation_method: {} use_missing_indicator_variables: {} imbalance_ratio: {} missingness_pattern: {} ratio_missing:{} ratio_per_class: {}".format(dataset_name, 
                                                                                                                                                                                                                    approach,
                                                                                                                                                                                                                    missing_data_handling,
                                                                                                                                                                                                                    imputation_method, 
                                                                                                                                                                                                                    use_missing_indicator_variables,
                                                                                                                                                                                                                    imbalance_ratio,
                                                                                                                                                                                                                    missingness_pattern,
                                                                                                                                                                                                                    ratio_of_missing_values, 
                                                                                                                                                                                                                    ratio_missing_per_class))

                        try:
                            start_time = time()

                            dataset = DatasetGenerator(dataset_name=dataset_name, 
                                                    num_samples=num_samples, 
                                                    imbalance_ratio=imbalance_ratio, 
                                                    missing_data_handling=missing_data_handling,
                                                    imputation_method=imputation_method,
                                                    verbosity=verbosity)

                            # Creation of the missingness
                            dataset.generate_missing_coordinates(missingness_pattern=missingness_pattern, 
                                                                 ratio_of_missing_values=ratio_of_missing_values, 
                                                                 ratio_missing_per_class=ratio_missing_per_class)

                            dataset.split_test_train()

                            # Create the experiments
                            exp = Experiments(dataset_name, 
                                              dataset=dataset, 
                                              purpose='classification', 
                                              approach = approach, 
                                              use_missing_indicator_variables=use_missing_indicator_variables,
                                              previous_experiment=None, 
                                              save_experiment=save, 
                                              verbosity=verbosity, 
                                              debug=False, 
                                              proportion_train=PROPORTION_TRAIN, 
                                              resolution=RESOLUTION, 
                                              bandwidth=BANDWIDTH,
                                              random_state=RANDOM_STATE)


                            # Estimate the distributions 
                            exp.fit()

                            # Estimate the distributions 
                            exp.predict()

                            # Plot results
                            #exp.plot()


                            end_time = time()

                            hours, rest = divmod(end_time - start_time, 3600)
                            minutes, seconds = divmod(rest, 60)
                            print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
                        except:
                            print("/!\. Error!\n")
                            print("{} - {} - missing_data_handling {} imputation_method: {} use_missing_indicator_variables: {} imbalance_ratio: {} missingness_pattern: {} ratio_missing:{} ratio_per_class: {}".format(dataset_name, 
                                                                                                                                                                                                                    approach,
                                                                                                                                                                                                                    missing_data_handling,
                                                                                                                                                                                                                    imputation_method, 
                                                                                                                                                                                                                    use_missing_indicator_variables,
                                                                                                                                                                                                                    imbalance_ratio,
                                                                                                                                                                                                                    missingness_pattern,
                                                                                                                                                                                                                    ratio_of_missing_values, 
                                                                                                                                                                                                                    ratio_missing_per_class))
# Out:
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 516!
# Done (0h 0m and 0.70s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 518!
# Done (0h 0m and 51.51s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 523!
# Done (0h 1m and 30.37s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 527!
# Done (0h 1m and 51.28s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 528!
# Done (0h 0m and 0.39s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 531!
# Done (0h 1m and 23.95s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 536!
# Done (0h 1m and 58.30s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 542!
# Done (0h 2m and 1.97s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 3 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 543!
# Done (0h 0m and 0.43s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 3 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 544!
# Done (0h 0m and 50.01s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 3 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 547!
# Done (0h 1m and 30.64s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 3 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 551!
# Done (0h 1m and 57.18s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 555!
# Done (0h 1m and 38.25s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 561!
# Done (0h 2m and 1.67s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 563!
# Done (0h 1m and 6.72s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 565!
# Done (0h 1m and 40.77s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 284!
# Done (0h 0m and 0.40s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 285!
# Done (0h 0m and 44.26s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 289!
# Done (0h 1m and 24.96s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 291!
# Done (0h 2m and 1.08s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 292!
# Done (0h 0m and 0.47s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 293!
# Done (0h 1m and 18.60s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 296!
# Done (0h 1m and 51.67s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 298!
# Done (0h 2m and 12.09s).
#
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 299!
# Done (0h 1m and 36.79s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 300!
# Done (0h 2m and 8.03s).
#
# Not doing this.
# Not doing this.
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 614!
# Done (0h 0m and 0.64s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 615!
# Done (0h 0m and 47.70s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 617!
# Done (0h 1m and 29.65s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 619!
# Done (0h 1m and 59.32s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 620!
# Done (0h 0m and 0.44s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 623!
# Done (0h 1m and 14.63s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 626!
# Done (0h 1m and 59.19s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 628!
# Done (0h 2m and 5.61s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 3 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 629!
# Done (0h 0m and 0.41s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 3 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 631!
# Done (0h 0m and 46.24s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 3 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 632!
# Done (0h 1m and 29.53s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 3 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 635!
# Done (0h 2m and 0.26s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 637!
# Done (0h 1m and 26.28s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 638!
# Done (0h 2m and 7.11s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 639!
# Done (0h 1m and 21.79s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.5 missingness_pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 640!
# Done (0h 1m and 47.03s).
#
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 608!
# Done (0h 0m and 0.62s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 611!
# Done (0h 0m and 49.44s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 614!
# Done (0h 1m and 30.52s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 619!
# Done (0h 1m and 53.59s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 620!
# Done (0h 0m and 0.48s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 624!
# Done (0h 1m and 23.30s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 627!
# Done (0h 1m and 55.58s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 632!
# Done (0h 2m and 4.63s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 3 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 633!
# Done (0h 0m and 0.38s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 3 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 637!
# Done (0h 0m and 52.76s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 3 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 642!
# Done (0h 1m and 31.99s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 3 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 645!
# Done (0h 1m and 58.84s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 647!
# Done (0h 0m and 54.88s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 650!
# Done (0h 1m and 45.96s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 652!
# Done (0h 0m and 35.49s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 655!
# Done (0h 1m and 30.18s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 307!
# Done (0h 0m and 0.65s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 309!
# Done (0h 0m and 45.41s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 310!
# Done (0h 1m and 28.35s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 313!
# Done (0h 1m and 57.93s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 314!
# Done (0h 0m and 0.45s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 316!
# Done (0h 1m and 17.61s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 317!
# Done (0h 2m and 0.62s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 318!
# Done (0h 2m and 12.01s).
#
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 319!
# Done (0h 0m and 52.53s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 320!
# Done (0h 1m and 51.92s).
#
# Not doing this.
# Not doing this.
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 648!
# Done (0h 0m and 0.42s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 649!
# Done (0h 0m and 45.90s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 652!
# Done (0h 1m and 33.30s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 655!
# Done (0h 2m and 9.69s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 656!
# Done (0h 0m and 0.57s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 657!
# Done (0h 1m and 14.74s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 660!
# Done (0h 1m and 57.05s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 663!
# Done (0h 2m and 9.34s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 3 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 664!
# Done (0h 0m and 0.63s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 3 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 666!
# Done (0h 0m and 45.86s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 3 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 667!
# Done (0h 1m and 25.91s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 3 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 668!
# Done (0h 1m and 59.72s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 669!
# Done (0h 0m and 53.56s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 670!
# Done (0h 1m and 50.99s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 671!
# Done (0h 0m and 50.00s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.25 missingness_pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 672!
# Done (0h 1m and 45.60s).
#
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 700!
# Done (0h 0m and 0.70s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 704!
# Done (0h 0m and 55.79s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 708!
# Done (0h 1m and 37.60s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 711!
# Done (0h 2m and 0.77s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 712!
# Done (0h 0m and 0.68s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 715!
# Done (0h 1m and 28.34s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 718!
# Done (0h 2m and 0.64s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 721!
# Done (0h 2m and 19.20s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 3 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 722!
# Done (0h 0m and 0.44s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 3 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 723!
# Done (0h 0m and 54.12s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 3 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 724!
# Done (0h 1m and 31.50s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 3 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 726!
# Done (0h 2m and 2.58s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 727!
# Done (0h 0m and 24.50s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 728!
# Done (0h 1m and 46.37s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 729!
# Done (0h 0m and 16.28s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 730!
# Done (0h 1m and 19.68s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 343!
# Done (0h 0m and 0.51s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 344!
# Done (0h 0m and 54.90s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 348!
# Done (0h 1m and 38.31s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 350!
# Done (0h 1m and 59.80s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 351!
# Done (0h 0m and 0.42s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 353!
# Done (0h 1m and 34.08s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 355!
# Done (0h 2m and 11.00s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 362!
# Done (0h 1m and 44.34s).
#
# Not doing this.
# Not doing this.
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 683!
# Done (0h 0m and 0.53s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 685!
# Done (0h 0m and 55.71s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 686!
# Done (0h 1m and 37.06s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 689!
# Done (0h 2m and 1.72s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 690!
# Done (0h 0m and 0.74s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 693!
# Done (0h 1m and 32.63s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 695!
# Done (0h 2m and 6.67s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 696!
# Done (0h 2m and 16.94s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 3 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 697!
# Done (0h 0m and 0.52s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 3 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 698!
# Done (0h 0m and 55.30s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 3 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 699!
# Done (0h 1m and 30.44s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 3 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 700!
# Done (0h 1m and 47.90s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 701!
# Done (0h 0m and 23.57s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 702!
# Done (0h 1m and 40.02s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 703!
# Done (0h 0m and 20.44s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: False imbalance_ratio: 0.1 missingness_pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 704!
# Done (0h 1m and 33.17s).
#
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 750!
# Done (0h 0m and 0.88s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 751!
# Done (0h 0m and 55.66s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 753!
# Done (0h 1m and 43.61s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 756!
# Done (0h 2m and 15.84s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 757!
# Done (0h 0m and 0.80s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 759!
# Done (0h 1m and 43.71s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 762!
# Done (0h 2m and 20.63s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 764!
# Done (0h 2m and 38.69s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 3 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 765!
# Done (0h 0m and 0.83s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 3 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 766!
# Done (0h 1m and 1.99s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 3 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 767!
# Done (0h 1m and 47.28s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 3 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 769!
# Done (0h 2m and 11.50s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 770!
# Done (0h 2m and 1.71s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 772!
# Done (0h 2m and 42.68s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 773!
# Done (0h 1m and 24.26s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 774!
# Done (0h 1m and 57.89s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 404!
# Done (0h 0m and 0.45s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 407!
# Done (0h 1m and 4.90s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 409!
# Done (0h 1m and 40.19s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 411!
# Done (0h 1m and 54.92s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 412!
# Done (0h 0m and 0.47s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 413!
# Done (0h 1m and 18.69s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 416!
# Done (0h 2m and 2.22s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 418!
# Done (0h 2m and 0.86s).
#
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 419!
# Done (0h 1m and 55.05s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 420!
# Done (0h 2m and 33.05s).
#
# Not doing this.
# Not doing this.
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 722!
# Done (0h 0m and 0.71s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 725!
# Done (0h 0m and 59.34s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 727!
# Done (0h 1m and 51.23s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 732!
# Done (0h 2m and 19.21s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 733!
# Done (0h 0m and 0.60s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 735!
# Done (0h 1m and 38.92s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 738!
# Done (0h 2m and 31.34s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 741!
# Done (0h 2m and 21.56s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 3 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 742!
# Done (0h 0m and 0.68s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 3 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 743!
# Done (0h 0m and 54.62s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 3 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 745!
# Done (0h 1m and 32.40s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 3 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 747!
# Done (0h 2m and 2.64s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 751!
# Done (0h 1m and 45.16s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 753!
# Done (0h 2m and 8.17s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 756!
# Done (0h 1m and 26.30s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.5 missingness_pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 758!
# Done (0h 2m and 18.27s).
#
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 798!
# Done (0h 0m and 0.77s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 800!
# Done (0h 1m and 3.70s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 802!
# Done (0h 1m and 31.04s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 805!
# Done (0h 2m and 37.25s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 806!
# Done (0h 0m and 0.71s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 807!
# Done (0h 1m and 59.22s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 808!
# Done (0h 2m and 0.06s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 810!
# Done (0h 2m and 8.06s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 3 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 811!
# Done (0h 0m and 0.48s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 3 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 812!
# Done (0h 0m and 51.38s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 3 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 814!
# Done (0h 1m and 29.87s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 3 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 815!
# Done (0h 1m and 59.13s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 816!
# Done (0h 0m and 50.09s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 818!
# Done (0h 1m and 44.76s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 819!
# Done (0h 0m and 37.66s).
#
# circles - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 820!
# Done (0h 1m and 30.45s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 431!
# Done (0h 0m and 0.55s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 432!
# Done (0h 0m and 45.11s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 433!
# Done (0h 1m and 24.18s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 434!
# Done (0h 1m and 56.42s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 435!
# Done (0h 0m and 0.91s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 436!
# Done (0h 1m and 19.96s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 437!
# Done (0h 1m and 59.87s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 438!
# Done (0h 2m and 16.21s).
#
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 439!
# Done (0h 0m and 52.35s).
#
# moons - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 440!
# Done (0h 1m and 50.71s).
#
# Not doing this.
# Not doing this.
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 799!
# Done (0h 0m and 0.71s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 802!
# Done (0h 0m and 47.30s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 805!
# Done (0h 1m and 29.00s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 807!
# Done (0h 1m and 58.38s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 808!
# Done (0h 0m and 0.46s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 811!
# Done (0h 1m and 14.06s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 813!
# Done (0h 1m and 59.99s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 815!
# Done (0h 2m and 5.25s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 3 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 816!
# Done (0h 0m and 0.43s).
#
# blobs - DecisionTree - missing_data_handling imputation imputation_method: multi_dimensional_weighting use_missing_indicator_variables: True imbalance_ratio: 0.25 missingness_pattern: 3 ratio_missing:0.1 ratio_per_class: None

# %% [markdown]
# # Create final dataset

# %%
df_final = pd.DataFrame(columns = ['dataset_name','experiment_number', 'approach', 'missing_data_handling','imputation_method', 'use_missing_indicator_variables', 
                                'num_samples', 'imbalance_ratio', 'missingness_pattern', 'missingness_mechanism', 
                                'ratio_of_missing_values', 'missing_X1', 'missing_X2', 'missing_first_quarter','ratio_missing_per_class_0', 'ratio_missing_per_class_1','auc',
                                'Accuracy', 'F1', 'MCC', 'Sensitivity', 'Specificity', 'Precision', 'PPV', 'NPV', 'FNR', 'FDR', 'FOR', 
                                'resolution', 'bandwidth', 'estimation_time_0', 'estimation_time_1'])

# %%
df = create_df(folder_names=['experiments_29_june_duke'])
df = df.append(pd.read_csv("/home01/sam/df_all_experiments.csv"))
df
# Out:
#     dataset_name  experiment_number             approach missing_data_handling imputation_method use_missing_indicator_variables num_samples  imbalance_ratio  missingness_pattern missingness_mechanism  ratio_of_missing_values missing_X1 missing_X2 missing_first_quarter  ratio_missing_per_class_0  ratio_missing_per_class_1  auc  Accuracy     F1    MCC  Sensitivity  Specificity  Precision    PPV    NPV    FNR    FDR    FOR resolution  bandwidth  estimation_time_0  estimation_time_1
# 0        circles                428         DecisionTree              encoding           without                            True        5000             0.50                    2                   MAR                      0.0       True       True                  True                        NaN                        NaN  NaN     0.835  0.851  0.690        0.952        0.720      0.770  0.770  0.938  0.048  0.230  0.062         20        0.2                NaN                NaN
# 1        circles                273  multi_distributions               without           without                           False        5000             0.50                    4                  MNAR                      NaN       True       True                 False                        0.1                       0.30  NaN     0.567  0.582  0.136        0.611        0.524      0.556  0.556  0.580  0.389  0.444  0.420         20        0.2                NaN                NaN
# 2        circles                457         DecisionTree              encoding           without                            True        5000             0.25                    1                  MCAR                      0.2       True      False                  None                        NaN                        NaN  NaN     0.732  0.638  0.524        0.944        0.661      0.482  0.482  0.973  0.056  0.518  0.027         20        0.2                NaN                NaN
# 3        circles                417         DecisionTree              encoding           without                           False        5000             0.10                    5                  MNAR                      NaN       True       True                  True                        0.0                       0.21  NaN     0.919  0.409  0.485        0.257        1.000      1.000  1.000  0.917  0.743  0.000  0.083         20        0.2                NaN                NaN
# 4        circles                346   LogisticRegression              encoding           without                           False        5000             0.25                    4                  MNAR                      NaN       True       True                 False                        0.1                       0.30  NaN     0.757  0.123  0.152        0.068        0.988      0.654  0.654  0.760  0.932  0.346  0.240         20        0.2                NaN                NaN
# ..           ...                ...                  ...                   ...               ...                             ...         ...              ...                  ...                   ...                      ...        ...        ...                   ...                        ...                        ...  ...       ...    ...    ...          ...          ...        ...    ...    ...    ...    ...    ...        ...        ...                ...                ...
# 862        blobs                 13              xgboost              encoding           without                            True        5000             0.50                    2                   MAR                      0.0       True       True                  True                        NaN                        NaN  NaN     0.979  0.979  0.958        0.980        0.978      0.978  0.978  0.980  0.020  0.022  0.020         20        0.2                NaN                NaN
# 863        blobs                  5              xgboost               without           without                            True        5000             0.50                    4                  MNAR                      NaN       True       True                 False                        0.0                       0.25  NaN     0.984  0.984  0.968        0.978        0.990      0.990  0.990  0.978  0.022  0.010  0.022         20        0.2                NaN                NaN
# 864        blobs                 14              xgboost              encoding           without                            True        5000             0.50                    2                   MAR                      0.1       True       True                  True                        NaN                        NaN  NaN     0.938  0.937  0.876        0.935        0.941      0.939  0.939  0.938  0.065  0.061  0.062         20        0.2                NaN                NaN
# 865        blobs                 22              xgboost              encoding           without                            True        5000             0.50                    4                  MNAR                      NaN       True       True                 False                        0.1                       0.30  NaN     0.946  0.947  0.893        0.968        0.924      0.927  0.927  0.967  0.032  0.073  0.033         20        0.2                NaN                NaN
# 866        blobs                 25              xgboost              encoding           without                            True        5000             0.50                    1                  MCAR                      0.0       True      False                   NaN                        NaN                        NaN  NaN     0.979  0.979  0.958        0.980        0.978      0.978  0.978  0.980  0.020  0.022  0.020         20        0.2                NaN                NaN
#
# [2190 rows x 32 columns]

# %%
"""  Fix parameters """
#Dataset default parameters
num_samples = NUM_SAMPLES

# pdf estimation default parameters
resolution = RESOLUTION
bandwidth = BANDWIDTH

# Classification default parameters
proportion_train = PROPORTION_TRAIN

# Verbosity
verbosity=0

save=True

missingness_dictionnary = {1: (range_ratio_of_missing_values, len(range_ratio_of_missing_values)*[None]),
                           2: (range_ratio_of_missing_values, len(range_ratio_of_missing_values)*[None]),
                           3: (range_ratio_of_missing_values, len(range_ratio_of_missing_values)*[None]),
                           4: (len(range_ratio_missing_per_class)*[None], range_ratio_missing_per_class),
                           5: (len(range_ratio_missing_per_class)*[None], range_ratio_missing_per_class)}

n = 0

for use_missing_indicator_variables in range_use_missing_indicator_variables:
    
    for imbalance_ratio in range_imbalance_ratio:
        
        
        for missing_data_handling in range_missing_data_handling:


            for dataset_name in range_dataset_name:


                for missingness_pattern, (ratio_of_missing_values_list, ratio_missing_per_class_list) in missingness_dictionnary.items():

                    for ratio_of_missing_values, ratio_missing_per_class in zip(ratio_of_missing_values_list, ratio_missing_per_class_list):



                        
                        n+=1
                        


                        if check_experiment_already_done(df, 
                                                          dataset_name=dataset_name, 
                                                          approach=approach,
                                                          imbalance_ratio=imbalance_ratio, 
                                                          missingness_pattern=missingness_pattern, 
                                                          imputation_method=imputation_method,
                                                          missing_data_handling=missing_data_handling, 
                                                          use_missing_indicator_variables=use_missing_indicator_variables,
                                                          ratio_of_missing_values=ratio_of_missing_values, 
                                                          ratio_missing_per_class_0=ratio_missing_per_class[0] if ratio_missing_per_class is not None else None):
                            
                            
                            iter_df = check_experiment_already_done(df, 
                                                          dataset_name=dataset_name, 
                                                          approach=approach,
                                                          imbalance_ratio=imbalance_ratio, 
                                                          missingness_pattern=missingness_pattern, 
                                                          imputation_method=imputation_method,
                                                          missing_data_handling=missing_data_handling, 
                                                          use_missing_indicator_variables=use_missing_indicator_variables,
                                                          ratio_of_missing_values=ratio_of_missing_values, 
                                                          ratio_missing_per_class_0=ratio_missing_per_class[0] if ratio_missing_per_class is not None else None, return_df = True)
                            
                            if len(iter_df) > 1:
                                df_final = df_final.append(iter_df.iloc[:1])
                                
                            else:
                                df_final = df_final.append(iter_df.iloc[:1])


                            continue
                        if (dataset_name == 'moons' and missingness_pattern in [3, 5]) or (range_ratio_of_missing_values==0 and missingness_pattern != 1):
                            n-=1
                            continue
                            
                            
                            
                        print("{} - imputation method: {} missing_data_handling: {} imbalance: {} pattern: {} ratio_missing:{} ratio_per_class: {}".format(dataset_name, 
                                                                                                                                                        missing_data_handling,
                                                                                                                                                          imputation_method, 
                                                                                                                                                          imbalance_ratio,
                                                                                                                                                          missingness_pattern,
                                                                                                                                                          ratio_of_missing_values, 
                                                                                                                                                              ratio_missing_per_class))

# %%
df_final
# Out:
#     dataset_name experiment_number      approach missing_data_handling imputation_method use_missing_indicator_variables num_samples  imbalance_ratio missingness_pattern missingness_mechanism  ratio_of_missing_values missing_X1 missing_X2 missing_first_quarter  ratio_missing_per_class_0  ratio_missing_per_class_1  auc  Accuracy     F1    MCC  Sensitivity  Specificity  Precision    PPV    NPV    FNR    FDR    FOR resolution  bandwidth  estimation_time_0  estimation_time_1
# 70       circles               333  DecisionTree              encoding           without                           False        5000              0.5                   1                  MCAR                      0.0       True      False                  None                        NaN                        NaN  NaN     0.835  0.851  0.690        0.952        0.720      0.770  0.770  0.938  0.048  0.230  0.062         20        0.2                NaN                NaN
# 256      circles               334  DecisionTree              encoding           without                           False        5000              0.5                   1                  MCAR                      0.1       True      False                  None                        NaN                        NaN  NaN     0.819  0.843  0.654        0.940        0.689      0.765  0.765  0.915  0.060  0.235  0.085         20        0.2                NaN                NaN
# 371      circles               336  DecisionTree              encoding           without                           False        5000              0.5                   1                  MCAR                      0.2       True      False                  None                        NaN                        NaN  NaN     0.813  0.834  0.656        0.957        0.673      0.739  0.739  0.942  0.043  0.261  0.058         20        0.2                NaN                NaN
# 5        circles               338  DecisionTree              encoding           without                           False        5000              0.5                   1                  MCAR                      0.3       True      False                  None                        NaN                        NaN  NaN     0.793  0.814  0.624        0.952        0.649      0.711  0.711  0.937  0.048  0.289  0.063         20        0.2                NaN                NaN
# 422      circles               339  DecisionTree              encoding           without                           False        5000              0.5                   2                   MAR                      0.0       True       True                  True                        NaN                        NaN  NaN     0.835  0.851  0.690        0.952        0.720      0.770  0.770  0.938  0.048  0.230  0.062         20        0.2                NaN                NaN
# ..           ...               ...           ...                   ...               ...                             ...         ...              ...                 ...                   ...                      ...        ...        ...                   ...                        ...                        ...  ...       ...    ...    ...          ...          ...        ...    ...    ...    ...    ...    ...        ...        ...                ...                ...
# 546        blobs               590  DecisionTree              encoding           without                            True        5000              0.1                   3                   MAR                      0.3       True      False                  True                        NaN                        NaN  NaN     0.963  0.804  0.804        0.673        1.000      1.000  1.000  0.960  0.327  0.000  0.040         20        0.2                NaN                NaN
# 992        blobs               591  DecisionTree              encoding           without                            True        5000              0.1                   4                  MNAR                      NaN       True       True                 False                        0.0                       0.25  NaN     0.990  0.952  0.947        0.952        0.994      0.952  0.952  0.994  0.048  0.048  0.006         20        0.2                NaN                NaN
# 533        blobs               592  DecisionTree              encoding           without                            True        5000              0.1                   4                  MNAR                      NaN       True       True                 False                        0.1                       0.30  NaN     0.957  0.775  0.758        0.692        0.989      0.881  0.881  0.964  0.308  0.119  0.036         20        0.2                NaN                NaN
# 746        blobs               593  DecisionTree              encoding           without                            True        5000              0.1                   5                  MNAR                      NaN       True       True                  True                        0.0                       0.25  NaN     0.992  0.952  0.948        0.941        0.997      0.964  0.964  0.995  0.059  0.036  0.005         20        0.2                NaN                NaN
# 684        blobs               594  DecisionTree              encoding           without                            True        5000              0.1                   5                  MNAR                      NaN       True       True                  True                        0.1                       0.30  NaN     0.960  0.800  0.778        0.816        0.976      0.784  0.784  0.980  0.184  0.216  0.020         20        0.2                NaN                NaN
#
# [252 rows x 32 columns]

# %%
assert n == len(df_final)

# %%
df_final.to_csv("/home01/sam/notes_on_stats/doc/src/data/experiemnt_8.csv", index=False)
