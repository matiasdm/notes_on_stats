# %% [markdown]
# # Development notebook. No experiments or results here. For dev purposes

# %%
run init.ipynb
# Out:
# Done.

# %%
df = create_df()

# %%
"""  Parameters of the experiment """
approach = 'single_distribution'

range_dataset_name = ['blobs', 'circles', 'moons']
range_ratio_of_missing_values = [0., 0.1, 0.2, 0.3]
range_ratio_missing_per_class = [[0,0.25], [0.1, 0.3]]
range_imbalance_ratio = [0.1, 0.25, 0.5]
range_missingness_pattern = [1, 3, 4, 5]

missing_data_handling = 'imputation'
range_imputation_method = ['mice', 'knn', 'mean', 'multi_dimensional_weighting']
use_missing_indicator_variables = False

# %%
"""  Fix parameters """
#Dataset default parameters
num_samples = NUM_SAMPLES

# pdf estimation default parameters
resolution = RESOLUTION
bandwidth = BANDWIDTH

# Classification default parameters
proportion_train = PROPORTION_TRAIN

# Verbosity
verbosity=0



save=True

missingness_dictionnary = {1: (range_ratio_of_missing_values, len(range_ratio_of_missing_values)*[None]),
                           2: (range_ratio_of_missing_values, len(range_ratio_of_missing_values)*[None]),
                           3: (range_ratio_of_missing_values, len(range_ratio_of_missing_values)*[None]),
                           4: (len(range_ratio_missing_per_class)*[None], range_ratio_missing_per_class),
                           5: (len(range_ratio_missing_per_class)*[None], range_ratio_missing_per_class)}

for dataset_name in range_dataset_name:
    
    for imbalance_ratio in range_imbalance_ratio:
        
        for imputation_method in range_imputation_method:

            for missingness_pattern, (ratio_of_missing_values_list, ratio_missing_per_class_list) in missingness_dictionnary.items():

                for ratio_of_missing_values, ratio_missing_per_class in zip(ratio_of_missing_values_list, ratio_missing_per_class_list):


                    if check_experiment_already_done(df, 
                                                      dataset_name=dataset_name, 
                                                      imbalance_ratio=imbalance_ratio, 
                                                      missingness_pattern=missingness_pattern, 
                                                      imputation_method=imputation_method,
                                                      use_missing_indicator_variables=use_missing_indicator_variables,
                                                      ratio_of_missing_values=ratio_of_missing_values, 
                                                      ratio_missing_per_class=ratio_missing_per_class):


                        print("Experiment already done.")
                        continue

                    print("{} - imputation method: {} missing_data_handling: {} imbalance: {} pattern: {} ratio_missing:{} ratio_per_class: {}".format(dataset_name, 
                                                                                                                                                        missing_data_handling,
                                                                                                                                                          imputation_method, 
                                                                                                                                                          imbalance_ratio,
                                                                                                                                                          missingness_pattern,
                                                                                                                                                          ratio_of_missing_values, 
                                                                                                                                                          ratio_missing_per_class))

                    try:
                        start_time = time()

                        dataset = DatasetGenerator(dataset_name=dataset_name, 
                                                num_samples=num_samples, 
                                                imbalance_ratio=imbalance_ratio, 
                                                missing_data_handling=missing_data_handling,
                                                imputation_method=imputation_method,
                                                verbosity=verbosity)

                        # Creation of the missingness
                        dataset.generate_missing_coordinates(missingness_pattern=missingness_pattern, 
                                                             ratio_of_missing_values=ratio_of_missing_values, 
                                                             ratio_missing_per_class=ratio_missing_per_class)

                        dataset.split_test_train()

                        # Create the experiments
                        exp = Experiments(dataset_name, 
                                          dataset=dataset, 
                                          purpose='classification', 
                                          approach = approach, 
                                          previous_experiment=None, 
                                          save_experiment=save, 
                                          verbosity=verbosity, 
                                          debug=False, 
                                          proportion_train=PROPORTION_TRAIN, 
                                          resolution=RESOLUTION, 
                                          bandwidth=BANDWIDTH,
                                          random_state=RANDOM_STATE)


                        # Estimate the distributions 
                        exp.fit()

                        # Estimate the distributions 
                        exp.predict()

                        # Plot results
                        #exp.plot()


                        end_time = time()

                        hours, rest = divmod(end_time - start_time, 3600)
                        minutes, seconds = divmod(rest, 60)
                        print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
                    except:
                        print("/!\. Error!\n")
# Out:
# 113
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 38!
# Done (0h 5m and 10.55s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 40!
# Done (0h 5m and 10.60s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 43!
# Done (0h 5m and 7.37s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 45!
# Done (0h 5m and 4.80s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 48!
# Done (0h 5m and 13.29s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 50!
# /!\. Error!
#
# 113
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 52!
# Done (0h 5m and 11.00s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 55!
# Done (0h 5m and 10.97s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 3 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 57!
# Done (0h 5m and 9.20s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 3 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 60!
# Done (0h 5m and 9.43s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 62!
# Done (0h 5m and 15.51s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 64!
# Done (0h 5m and 11.46s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 67!
# Done (0h 5m and 10.98s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 69!
# Done (0h 5m and 9.07s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 72!
# Done (0h 5m and 10.43s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 74!
# Done (0h 5m and 13.03s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 76!
# Done (0h 5m and 15.21s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 79!
# Done (0h 5m and 12.50s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 81!
# Done (0h 5m and 12.12s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 84!
# Done (0h 5m and 11.34s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 91!
# Done (0h 5m and 12.15s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 97!
# /!\. Error!
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 104!
# Done (0h 5m and 11.87s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 111!
# Done (0h 5m and 11.19s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 3 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 117!
# Done (0h 5m and 11.92s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 3 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 124!
# Done (0h 5m and 10.15s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 130!
# Done (0h 5m and 8.94s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 137!
# Done (0h 5m and 21.81s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 144!
# Done (0h 5m and 9.46s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 150!
# Done (0h 5m and 13.52s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 158!
# Done (0h 4m and 37.16s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 160!
# Done (0h 4m and 26.69s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 162!
# Done (0h 4m and 29.54s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 164!
# Done (0h 4m and 28.94s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 167!
# Done (0h 4m and 29.29s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 169!
# Done (0h 4m and 28.70s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 171!
# Done (0h 4m and 28.35s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 173!
# /!\. Error!
#
# 113
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 175!
# Done (0h 4m and 29.43s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 178!
# Done (0h 4m and 29.43s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 3 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 180!
# Done (0h 4m and 30.53s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 3 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 182!
# Done (0h 4m and 30.68s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 184!
# Done (0h 4m and 29.41s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 186!
# Done (0h 4m and 28.90s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 189!
# Done (0h 4m and 28.06s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 191!
# Done (0h 4m and 28.27s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 193!
# Done (0h 4m and 28.23s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 195!
# Done (0h 4m and 30.57s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 197!
# Done (0h 4m and 30.47s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 200!
# Done (0h 5m and 16.91s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 202!
# Done (0h 5m and 53.08s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 205!
# Done (0h 6m and 18.88s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 207!
# Done (0h 4m and 29.32s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 210!
# /!\. Error!
#
# 113
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 213!
# Done (0h 6m and 21.98s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 216!
# Done (0h 6m and 27.88s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 3 ratio_missing:0.0 ratio_per_class: None
# Doing experiment
).
#
# 113
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 324!
# Done (0h 4m and 37.88s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.5 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 325!
# Done (0h 4m and 38.63s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.5 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 326!
# Done (0h 4m and 37.20s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.5 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 327!
# /!\. Error!
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.5 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 328!
# Done (0h 4m and 37.42s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.5 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 329!
# Done (0h 8m and 5.86s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.5 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 330!
# Done (0h 7m and 6.29s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.5 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 331!
# Done (0h 4m and 44.23s).
#
# 113
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.5 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 332!

# %%
"""  Fix parameters """
#Dataset default parameters
num_samples = NUM_SAMPLES

# pdf estimation default parameters
resolution = RESOLUTION
bandwidth = BANDWIDTH

# Classification default parameters
proportion_train = PROPORTION_TRAIN

# Verbosity
verbosity=0



save=True

missingness_dictionnary = {1: (range_ratio_of_missing_values, len(range_ratio_of_missing_values)*[None]),
                           2: (range_ratio_of_missing_values, len(range_ratio_of_missing_values)*[None]),
                           3: (range_ratio_of_missing_values, len(range_ratio_of_missing_values)*[None]),
                           4: (len(range_ratio_missing_per_class)*[None], range_ratio_missing_per_class),
                           5: (len(range_ratio_missing_per_class)*[None], range_ratio_missing_per_class)}

for dataset_name in range_dataset_name:
    
    for imbalance_ratio in range_imbalance_ratio:
        
        for imputation_method in range_imputation_method:

            for missingness_pattern, (ratio_of_missing_values_list, ratio_missing_per_class_list) in missingness_dictionnary.items():

                for ratio_of_missing_values, ratio_missing_per_class in zip(ratio_of_missing_values_list, ratio_missing_per_class_list):


                    if check_experiment_already_done(df, 
                                                      dataset_name=dataset_name, 
                                                      imbalance_ratio=imbalance_ratio, 
                                                      missingness_pattern=missingness_pattern, 
                                                      imputation_method=imputation_method,
                                                      use_missing_indicator_variables=use_missing_indicator_variables,
                                                      ratio_of_missing_values=ratio_of_missing_values, 
                                                      ratio_missing_per_class=ratio_missing_per_class):


                        print("Experiment already done.")
                        continue

                    print("{} - imputation method: {} missing_data_handling: {} imbalance: {} pattern: {} ratio_missing:{} ratio_per_class: {}".format(dataset_name, 
                                                                                                                                                        missing_data_handling,
                                                                                                                                                          imputation_method, 
                                                                                                                                                          imbalance_ratio,
                                                                                                                                                          missingness_pattern,
                                                                                                                                                          ratio_of_missing_values, 
                                                                                                                                                          ratio_missing_per_class))


                    start_time = time()

                    dataset = DatasetGenerator(dataset_name=dataset_name, 
                                            num_samples=num_samples, 
                                            imbalance_ratio=imbalance_ratio, 
                                            missing_data_handling=missing_data_handling,
                                            imputation_method=imputation_method,
                                            verbosity=verbosity)

                    # Creation of the missingness
                    dataset.generate_missing_coordinates(missingness_pattern=missingness_pattern, 
                                                         ratio_of_missing_values=ratio_of_missing_values, 
                                                         ratio_missing_per_class=ratio_missing_per_class)

                    dataset.split_test_train()

                    # Create the experiments
                    exp = Experiments(dataset_name, 
                                      dataset=dataset, 
                                      purpose='classification', 
                                      approach = approach, 
                                      previous_experiment=None, 
                                      save_experiment=save, 
                                      verbosity=verbosity, 
                                      debug=False, 
                                      proportion_train=PROPORTION_TRAIN, 
                                      resolution=RESOLUTION, 
                                      bandwidth=BANDWIDTH,
                                      random_state=RANDOM_STATE)


                    # Estimate the distributions 
                    exp.fit()

                    # Estimate the distributions 
                    exp.predict()

                    # Plot results
                    #exp.plot()


                    end_time = time()

                    hours, rest = divmod(end_time - start_time, 3600)
                    minutes, seconds = divmod(rest, 60)
                    print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
                #except:
                #    print("/!\. Error!\n")
# Out:
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 1!
# Done (0h 5m and 9.40s).
#
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 4!
# Done (0h 5m and 57.81s).
#
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 7!
# Done (0h 6m and 40.37s).
#
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 10!
# Done (0h 7m and 6.25s).
#
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 12!
# Done (0h 5m and 7.50s).
#
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 15!
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-ef69e6f3dc27> in <module>
#      91
#      92                     # Estimate the distributions
# ---> 93                     exp.predict()
#      94
#      95                     # Plot results
#
# ~/Duke/work/notes_on_stats/doc/src/experiments.py in predict(self)
#     146
#     147             # Do the prediction for the test set.
# --> 148             self._predict_map()
#     149
#     150             # Compute performances
#
# ~/Duke/work/notes_on_stats/doc/src/experiments.py in _predict_map(self)
#     814
#     815         # Compare likelihood to do the prediction
# --> 816         y_pred_both_known = (self.dist_pos.f[tuple(inds_array)] > self.dist_neg.f[tuple(inds_array)]).astype(int)
#     817
#     818         # Assign predictions
#
# IndexError: index 36 is out of bounds for axis 1 with size 30
