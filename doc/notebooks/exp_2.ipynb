# %% [markdown]
# # Development notebook. No experiments or results here. For dev purposes

# %%
run init.ipynb
# Out:
# Done.

# %%
"""  Parameters of the experiment """
approach = 'single_distribution'

range_dataset_name = ['blobs', 'circles', 'moons']
range_ratio_of_missing_values = [0., 0.1, 0.2, 0.3]
range_ratio_missing_per_class = [[0,0.25], [0.1, 0.3]]
range_imbalance_ratio = [0.5, 0.25, 0.1]
range_missingness_pattern = [1, 3, 4, 5]

missing_data_handling = 'imputation'
range_imputation_method = ['mice', 'knn', 'mean', 'multi_dimensional_weighting']
use_missing_indicator_variables = None

# %%
df = create_df(folder_names=['experiments_29_june_duke'])
df = df.append(pd.read_csv("/home01/sam/df_all_experiments.csv"))

# %%
df
# Out:
#     dataset_name  experiment_number approach missing_data_handling imputation_method use_missing_indicator_variables num_samples  imbalance_ratio  missingness_pattern missingness_mechanism ratio_of_missing_values missing_X1 missing_X2 missing_first_quarter  ratio_missing_per_class_0  ratio_missing_per_class_1     auc  Accuracy      F1     MCC  Sensitivity  Specificity  Precision     PPV     NPV     FNR     FDR     FOR resolution  bandwidth  estimation_time_0  estimation_time_1
# 0        circles                188      nam              encoding           without                           False        5000              0.5                    3                   MAR                     0.3       True      False                  True                        NaN                        NaN  0.9469    0.8653  0.8711  0.7394       0.9346       0.8000     0.8159  0.8159  0.9282  0.0654  0.1841  0.0718         20        0.2                NaN                NaN
# 1        circles                156      ebm              encoding           without                            True        5000              0.1                    3                   MAR                     0.2       True      False                  True                        NaN                        NaN     NaN    0.9590  0.7450  0.7310       0.6590       0.9890     0.8570  0.8570  0.9670  0.3410  0.1430  0.0330         20        0.2                NaN                NaN
# 2        circles                186      nam              encoding           without                           False        5000              0.5                    3                   MAR                     0.1       True      False                  True                        NaN                        NaN  0.9762    0.9117  0.9146  0.8260       0.9492       0.8745     0.8831  0.8831  0.9455  0.0508  0.1169  0.0545         20        0.2                NaN                NaN
# 3        circles                150      ebm              encoding           without                            True        5000              0.1                    2                   MAR                     0.0       True       True                  True                        NaN                        NaN     NaN    0.9770  0.8830  0.8740       0.8210       0.9960     0.9560  0.9560  0.9790  0.1790  0.0440  0.0210         20        0.2                NaN                NaN
# 4        circles                212      nam              encoding           without                           False        5000              0.1                    1                  MCAR                     0.3       True      False                  None                        NaN                        NaN  0.9387    0.9024  0.0000     NaN       0.0000       1.0000        NaN     NaN  0.9024  1.0000     NaN  0.0976         20        0.2                NaN                NaN
# ..           ...                ...      ...                   ...               ...                             ...         ...              ...                  ...                   ...                     ...        ...        ...                   ...                        ...                        ...     ...       ...     ...     ...          ...          ...        ...     ...     ...     ...     ...     ...        ...        ...                ...                ...
# 862        blobs                 13  xgboost              encoding           without                            True        5000              0.5                    2                   MAR                     0.0       True       True                  True                        NaN                        NaN     NaN    0.9790  0.9790  0.9580       0.9800       0.9780     0.9780  0.9780  0.9800  0.0200  0.0220  0.0200         20        0.2                NaN                NaN
# 863        blobs                  5  xgboost               without           without                            True        5000              0.5                    4                  MNAR                     NaN       True       True                 False                        0.0                       0.25     NaN    0.9840  0.9840  0.9680       0.9780       0.9900     0.9900  0.9900  0.9780  0.0220  0.0100  0.0220         20        0.2                NaN                NaN
# 864        blobs                 14  xgboost              encoding           without                            True        5000              0.5                    2                   MAR                     0.1       True       True                  True                        NaN                        NaN     NaN    0.9380  0.9370  0.8760       0.9350       0.9410     0.9390  0.9390  0.9380  0.0650  0.0610  0.0620         20        0.2                NaN                NaN
# 865        blobs                 22  xgboost              encoding           without                            True        5000              0.5                    4                  MNAR                     NaN       True       True                 False                        0.1                       0.30     NaN    0.9460  0.9470  0.8930       0.9680       0.9240     0.9270  0.9270  0.9670  0.0320  0.0730  0.0330         20        0.2                NaN                NaN
# 866        blobs                 25  xgboost              encoding           without                            True        5000              0.5                    1                  MCAR                     0.0       True      False                   NaN                        NaN                        NaN     NaN    0.9790  0.9790  0.9580       0.9800       0.9780     0.9780  0.9780  0.9800  0.0200  0.0220  0.0200         20        0.2                NaN                NaN
#
# [1334 rows x 32 columns]

# %%
"""  Fix parameters """
#Dataset default parameters
num_samples = NUM_SAMPLES

# pdf estimation default parameters
resolution = RESOLUTION
bandwidth = BANDWIDTH

# Classification default parameters
proportion_train = PROPORTION_TRAIN

# Verbosity
verbosity=0



save=True

missingness_dictionnary = {1: (range_ratio_of_missing_values, len(range_ratio_of_missing_values)*[None]),
                           2: (range_ratio_of_missing_values, len(range_ratio_of_missing_values)*[None]),
                           3: (range_ratio_of_missing_values, len(range_ratio_of_missing_values)*[None]),
                           4: (len(range_ratio_missing_per_class)*[None], range_ratio_missing_per_class),
                           5: (len(range_ratio_missing_per_class)*[None], range_ratio_missing_per_class)}

for dataset_name in range_dataset_name:
    
    for imbalance_ratio in range_imbalance_ratio:
        
        for imputation_method in range_imputation_method:

            for missingness_pattern, (ratio_of_missing_values_list, ratio_missing_per_class_list) in missingness_dictionnary.items():

                for ratio_of_missing_values, ratio_missing_per_class in zip(ratio_of_missing_values_list, ratio_missing_per_class_list):


                    if check_experiment_already_done(df, 
                                                          dataset_name=dataset_name, 
                                                          approach=approach,
                                                          imbalance_ratio=imbalance_ratio, 
                                                          missingness_pattern=missingness_pattern, 
                                                          imputation_method=imputation_method,
                                                          missing_data_handling=missing_data_handling, 
                                                          use_missing_indicator_variables=use_missing_indicator_variables,
                                                          ratio_of_missing_values=ratio_of_missing_values, 
                                                          ratio_missing_per_class_0=ratio_missing_per_class[0] if ratio_missing_per_class is not None else None):


                        print("Experiment already done.")
                        continue
                    if (dataset_name == 'moons' and missingness_pattern in [3, 5]) or (range_ratio_of_missing_values==0 and missingness_pattern != 1):
                        print("Not doing this.")
                        continue
                    else:
                        print("Left to do")
# Out:
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Left to do
# Not doing this.
# Not doing this.
# Not doing this.
# Not doing this.
# Left to do
# Left to do
# Not doing this.
# Not doing this.

# %%
"""  Fix parameters """
#Dataset default parameters
num_samples = NUM_SAMPLES

# pdf estimation default parameters
resolution = RESOLUTION
bandwidth = BANDWIDTH

# Classification default parameters
proportion_train = PROPORTION_TRAIN

# Verbosity
verbosity=0



save=True

missingness_dictionnary = {1: (range_ratio_of_missing_values, len(range_ratio_of_missing_values)*[None]),
                           2: (range_ratio_of_missing_values, len(range_ratio_of_missing_values)*[None]),
                           3: (range_ratio_of_missing_values, len(range_ratio_of_missing_values)*[None]),
                           4: (len(range_ratio_missing_per_class)*[None], range_ratio_missing_per_class),
                           5: (len(range_ratio_missing_per_class)*[None], range_ratio_missing_per_class)}

for dataset_name in range_dataset_name:
    
    for imbalance_ratio in range_imbalance_ratio:
        
        for imputation_method in range_imputation_method:

            for missingness_pattern, (ratio_of_missing_values_list, ratio_missing_per_class_list) in missingness_dictionnary.items():

                for ratio_of_missing_values, ratio_missing_per_class in zip(ratio_of_missing_values_list, ratio_missing_per_class_list):


                    if check_experiment_already_done(df, 
                                                          dataset_name=dataset_name, 
                                                          approach=approach,
                                                          imbalance_ratio=imbalance_ratio, 
                                                          missingness_pattern=missingness_pattern, 
                                                          imputation_method=imputation_method,
                                                          missing_data_handling=missing_data_handling, 
                                                          use_missing_indicator_variables=use_missing_indicator_variables,
                                                          ratio_of_missing_values=ratio_of_missing_values, 
                                                          ratio_missing_per_class_0=ratio_missing_per_class[0] if ratio_missing_per_class is not None else None):


                        print("Experiment already done.")
                        continue
                        
                    if (dataset_name == 'moons' and missingness_pattern in [3, 5]) or (range_ratio_of_missing_values==0 and missingness_pattern != 1):
                        print("Not doing this.")
                        

                    print("{} - {} - missing_data_handling {} imputation_method: {} use_missing_indicator_variables: {} imbalance_ratio: {} missingness_pattern: {} ratio_missing:{} ratio_per_class: {}".format(dataset_name, 
                                                                                                                                                                                                                    approach,
                                                                                                                                                                                                                    missing_data_handling,
                                                                                                                                                                                                                    imputation_method, 
                                                                                                                                                                                                                    use_missing_indicator_variables,
                                                                                                                                                                                                                    imbalance_ratio,
                                                                                                                                                                                                                    missingness_pattern,
                                                                                                                                                                                                                    ratio_of_missing_values, 
                                                                                                                                                                                                                    ratio_missing_per_class))

                    try:
                        start_time = time()

                        dataset = DatasetGenerator(dataset_name=dataset_name, 
                                                num_samples=num_samples, 
                                                imbalance_ratio=imbalance_ratio, 
                                                missing_data_handling=missing_data_handling,
                                                imputation_method=imputation_method,
                                                verbosity=verbosity)

                        # Creation of the missingness
                        dataset.generate_missing_coordinates(missingness_pattern=missingness_pattern, 
                                                             ratio_of_missing_values=ratio_of_missing_values, 
                                                             ratio_missing_per_class=ratio_missing_per_class)

                        dataset.split_test_train()

                        # Create the experiments
                        exp = Experiments(dataset_name, 
                                          dataset=dataset, 
                                          purpose='classification', 
                                          approach = approach, 
                                          previous_experiment=None, 
                                          use_missing_indicator_variables=use_missing_indicator_variables,
                                          save_experiment=save, 
                                          verbosity=verbosity, 
                                          debug=False, 
                                          proportion_train=PROPORTION_TRAIN, 
                                          resolution=RESOLUTION, 
                                          bandwidth=BANDWIDTH,
                                          random_state=RANDOM_STATE)


                        # Estimate the distributions 
                        exp.fit()

                        # Estimate the distributions 
                        exp.predict()

                        # Plot results
                        #exp.plot()


                        end_time = time()

                        hours, rest = divmod(end_time - start_time, 3600)
                        minutes, seconds = divmod(rest, 60)
                        print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
                    except:
                        print("/!\. Error!\n")
                        print("{} - {} - missing_data_handling {} imputation_method: {} use_missing_indicator_variables: {} imbalance_ratio: {} missingness_pattern: {} ratio_missing:{} ratio_per_class: {}".format(dataset_name, 
                                                                                                                                                                                                                    approach,
                                                                                                                                                                                                                    missing_data_handling,
                                                                                                                                                                                                                    imputation_method, 
                                                                                                                                                                                                                    use_missing_indicator_variables,
                                                                                                                                                                                                                    imbalance_ratio,
                                                                                                                                                                                                                    missingness_pattern,
                                                                                                                                                                                                                    ratio_of_missing_values, 
                                                                                                                                                                                                                    ratio_missing_per_class))
# Out:
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 180!
# Done (0h 1m and 22.30s).
#
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 181!
# Done (0h 1m and 27.47s).
#
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 183!
# Done (0h 1m and 22.08s).
#
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 186!
# Done (0h 1m and 21.56s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 187!
# Done (0h 1m and 19.56s).
#
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 189!
# Done (0h 1m and 21.80s).
#
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 190!
# Done (0h 1m and 18.39s).
#
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 192!
# Done (0h 1m and 21.41s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 193!
# Done (0h 1m and 18.90s).
#
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 195!
# Done (0h 1m and 19.38s).
#
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 196!
# Done (0h 1m and 17.64s).
#
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 198!
# Done (0h 1m and 19.73s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 200!
# Done (0h 1m and 52.50s).
#
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 202!
# Done (0h 2m and 4.10s).
#
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 203!
# Done (0h 1m and 48.15s).
#
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 205!
# Done (0h 2m and 1.81s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 207!
# Done (0h 1m and 17.81s).
#
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 208!
# Done (0h 1m and 19.53s).
#
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 210!
# Done (0h 1m and 17.97s).
#
# Experiment already done.
# Experiment already done.
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 211!
# Done (0h 1m and 19.53s).
#
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 213!
# Done (0h 1m and 15.28s).
#
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 214!
# Done (0h 1m and 17.66s).
#
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 216!
# Done (0h 1m and 18.30s).
#
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 218!
# Done (0h 1m and 18.58s).
#
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 219!
# Done (0h 1m and 21.82s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 221!
# Done (0h 1m and 20.35s).
#
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 222!
# Done (0h 1m and 18.89s).
#
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 224!
# Done (0h 1m and 18.89s).
#
# Experiment already done.
# Experiment already done.
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 225!
# Done (0h 1m and 18.71s).
#
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 227!
# Done (0h 1m and 17.97s).
#
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 228!
# Done (0h 1m and 17.00s).
#
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 230!
# Done (0h 1m and 18.80s).
#
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 231!
# Done (0h 1m and 18.30s).
#
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 233!
# Done (0h 1m and 20.55s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 234!
# Done (0h 1m and 23.38s).
#
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 236!
# Done (0h 1m and 17.15s).
#
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 238!
# Done (0h 1m and 19.69s).
#
# Experiment already done.
# Experiment already done.
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 239!
# Done (0h 1m and 20.01s).
#
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 241!
# Done (0h 1m and 16.87s).
#
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 242!
# Done (0h 1m and 15.51s).
#
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 244!
# Done (0h 1m and 16.54s).
#
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 245!
# Done (0h 1m and 18.08s).
#
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 247!
# Done (0h 1m and 20.54s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 249!
# Done (0h 1m and 47.97s).
#
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 250!
# Done (0h 2m and 2.06s).
#
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 252!
# Done (0h 2m and 8.30s).
#
# Experiment already done.
# Experiment already done.
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 254!
# Done (0h 1m and 52.57s).
#
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 256!
# Done (0h 2m and 5.72s).
#
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 258!
# Done (0h 1m and 40.11s).
#
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 260!
# Done (0h 1m and 59.61s).
#
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 261!
# Done (0h 2m and 11.52s).
#
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 263!
# Done (0h 2m and 9.09s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 265!
# Done (0h 1m and 16.71s).
#
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 266!
# Done (0h 1m and 16.86s).
#
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 268!
# Done (0h 1m and 15.62s).
#
# blobs - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 269!
# Done (0h 1m and 17.13s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 270!
# Done (0h 1m and 16.56s).
#
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 271!
# Done (0h 1m and 16.36s).
#
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 272!
# Done (0h 1m and 16.13s).
#
# blobs - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 273!
# Done (0h 1m and 18.32s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 274!
# Done (0h 1m and 16.56s).
#
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 275!
# Done (0h 1m and 17.12s).
#
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 276!
# Done (0h 1m and 20.59s).
#
# blobs - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 277!
# Done (0h 1m and 18.42s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 278!
# Done (0h 1m and 25.28s).
#
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 279!
# Done (0h 1m and 53.61s).
#
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 280!
# Done (0h 1m and 23.77s).
#
# blobs - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 281!
# Done (0h 1m and 51.36s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# circles - imputation method: imputation missing_data_handling: mice imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 249!
# Done (0h 1m and 17.69s).
#
# circles - imputation method: imputation missing_data_handling: mice imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 251!
# Done (0h 1m and 18.09s).
#
# circles - imputation method: imputation missing_data_handling: mice imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 252!
# Done (0h 1m and 20.15s).
#
# circles - imputation method: imputation missing_data_handling: mice imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 254!
# Done (0h 1m and 22.86s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# circles - imputation method: imputation missing_data_handling: knn imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 255!
# Done (0h 1m and 17.74s).
#
# circles - imputation method: imputation missing_data_handling: knn imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 257!
# Done (0h 1m and 17.39s).
#
# circles - imputation method: imputation missing_data_handling: knn imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 258!
# Done (0h 1m and 21.24s).
#
# circles - imputation method: imputation missing_data_handling: knn imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 260!
# Done (0h 1m and 23.42s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# circles - imputation method: imputation missing_data_handling: mean imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 262!
# Done (0h 1m and 17.09s).
#
# circles - imputation method: imputation missing_data_handling: mean imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 263!
# Done (0h 1m and 19.83s).
#
# circles - imputation method: imputation missing_data_handling: mean imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 265!
# Done (0h 1m and 20.81s).
#
# circles - imputation method: imputation missing_data_handling: mean imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 266!
# Done (0h 1m and 24.52s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 268!
# Done (0h 1m and 54.72s).
#
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 270!
# Done (0h 2m and 5.57s).
#
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 272!
# Done (0h 1m and 42.00s).
#
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 273!
# Done (0h 1m and 57.21s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# circles - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 275!
# Done (0h 1m and 19.46s).
#
# circles - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 277!
# Done (0h 1m and 19.27s).
#
# circles - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 278!
# Done (0h 1m and 21.27s).
#
# circles - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 280!
# Done (0h 1m and 24.42s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# circles - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 281!
# Done (0h 1m and 18.51s).
#
# circles - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 283!
# Done (0h 1m and 19.69s).
#
# circles - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 284!
# Done (0h 1m and 21.86s).
#
# circles - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 286!
# Done (0h 1m and 21.72s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# circles - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 287!
# Done (0h 1m and 16.22s).
#
# circles - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 289!
# Done (0h 1m and 15.93s).
#
# circles - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 290!
# Done (0h 1m and 18.49s).
#
# circles - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 292!
# Done (0h 1m and 20.32s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 294!
# Done (0h 1m and 36.52s).
#
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 296!
# Done (0h 1m and 56.17s).
#
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 297!
# Done (0h 1m and 30.48s).
#
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 299!
# Done (0h 1m and 50.72s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# circles - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 301!
# Done (0h 1m and 16.67s).
#
# circles - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 302!
# Done (0h 1m and 15.99s).
#
# circles - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 304!
# Done (0h 1m and 18.50s).
#
# circles - imputation method: imputation missing_data_handling: mice imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 305!
# Done (0h 1m and 21.60s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# circles - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 307!
# Done (0h 1m and 18.67s).
#
# circles - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 308!
# Done (0h 1m and 18.01s).
#
# circles - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 310!
# Done (0h 1m and 18.90s).
#
# circles - imputation method: imputation missing_data_handling: knn imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 311!
# Done (0h 1m and 23.83s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# circles - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 313!
# Done (0h 1m and 18.14s).
#
# circles - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 314!
# Done (0h 1m and 18.02s).
#
# circles - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 316!
# Done (0h 1m and 18.86s).
#
# circles - imputation method: imputation missing_data_handling: mean imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 318!
# Done (0h 1m and 21.18s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 319!
# Done (0h 1m and 25.05s).
#
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 321!
# Done (0h 1m and 53.87s).
#
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 323!
# Done (0h 1m and 22.74s).
#
# circles - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.1 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 324!
# Done (0h 1m and 48.86s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# moons - imputation method: imputation missing_data_handling: mice imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 103!
# Done (0h 1m and 17.19s).
#
# moons - imputation method: imputation missing_data_handling: mice imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 104!
# Done (0h 1m and 16.67s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: mice imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 105!
# Done (0h 1m and 20.90s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: mice imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 106!
# Done (0h 1m and 22.05s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# moons - imputation method: imputation missing_data_handling: knn imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 107!
# Done (0h 1m and 16.73s).
#
# moons - imputation method: imputation missing_data_handling: knn imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 108!
# Done (0h 1m and 17.28s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: knn imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 109!
# Done (0h 1m and 22.80s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: knn imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 110!
# Done (0h 1m and 21.83s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# moons - imputation method: imputation missing_data_handling: mean imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 111!
# Done (0h 1m and 15.83s).
#
# moons - imputation method: imputation missing_data_handling: mean imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 112!
# Done (0h 1m and 17.34s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: mean imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 113!
# Done (0h 1m and 20.37s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: mean imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 114!
# Done (0h 1m and 26.06s).
#
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# Experiment already done.
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 115!
# Done (0h 1m and 51.18s).
#
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 116!
# Done (0h 2m and 8.53s).
#
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 117!
# Done (0h 2m and 10.33s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 118!
# Done (0h 1m and 20.29s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 119!
# Done (0h 1m and 38.28s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 120!
# Done (0h 1m and 55.28s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 122!
# Done (0h 1m and 59.86s).
#
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 123!
# Done (0h 1m and 52.57s).
#
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 125!
# Done (0h 2m and 4.60s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 127!
# Done (0h 1m and 29.43s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: multi_dimensional_weighting imbalance: 0.5 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 129!
# Done (0h 1m and 45.25s).
#
# moons - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 130!
# Done (0h 1m and 18.00s).
#
# moons - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 132!
# Done (0h 1m and 19.26s).
#
# moons - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 133!
# Done (0h 1m and 19.50s).
#
# moons - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 135!
# Done (0h 1m and 20.93s).
#
# moons - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 136!
# Done (0h 1m and 21.64s).
#
# moons - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 138!
# Done (0h 1m and 19.15s).
#
# moons - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 139!
# Done (0h 1m and 16.89s).
#
# moons - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 141!
# Done (0h 1m and 19.07s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 3 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 142!
# Done (0h 1m and 18.83s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 3 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 144!
# Done (0h 1m and 21.09s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 146!
# Done (0h 1m and 17.88s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 147!
# Done (0h 1m and 18.07s).
#
# moons - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 149!
# Done (0h 1m and 17.88s).
#
# moons - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 150!
# Done (0h 1m and 19.98s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 152!
# Done (0h 1m and 20.54s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: mice imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 153!
# Done (0h 1m and 22.23s).
#
# moons - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 155!
# Done (0h 1m and 18.82s).
#
# moons - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 156!
# Done (0h 1m and 15.99s).
#
# moons - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 158!
# Done (0h 1m and 16.00s).
#
# moons - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 159!
# Done (0h 1m and 16.21s).
#
# moons - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 161!
# Done (0h 1m and 15.82s).
#
# moons - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 162!
# Done (0h 1m and 16.93s).
#
# moons - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 164!
# Done (0h 1m and 19.70s).
#
# moons - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 165!
# Done (0h 1m and 19.28s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 3 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 167!
# Done (0h 1m and 19.05s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 3 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 169!
# Done (0h 1m and 22.30s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 170!
# Done (0h 1m and 21.73s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 172!
# Done (0h 1m and 18.65s).
#
# moons - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 173!
# Done (0h 1m and 19.85s).
#
# moons - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 175!
# Done (0h 1m and 19.19s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 176!
# Done (0h 21m and 44.87s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: knn imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 178!
# Done (0h 1m and 24.14s).
#
# moons - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 1 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 179!
# Done (0h 1m and 20.74s).
#
# moons - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 1 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 181!
# Done (0h 1m and 21.46s).
#
# moons - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 1 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 182!
# Done (0h 1m and 21.53s).
#
# moons - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 1 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 184!
# Done (0h 1m and 23.69s).
#
# moons - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 2 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 185!
# Done (0h 14m and 6.77s).
#
# moons - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 2 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 187!
# Done (0h 1m and 19.76s).
#
# moons - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 2 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 189!
# Done (0h 1m and 18.67s).
#
# moons - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 2 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 190!
# Done (0h 3m and 19.92s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 3 ratio_missing:0.0 ratio_per_class: None
# Doing experiment 192!
# Done (0h 1m and 23.01s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 3 ratio_missing:0.1 ratio_per_class: None
# Doing experiment 193!
# Done (0h 1m and 24.47s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 3 ratio_missing:0.2 ratio_per_class: None
# Doing experiment 195!
# Done (0h 1m and 30.68s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 3 ratio_missing:0.3 ratio_per_class: None
# Doing experiment 196!
# Done (0h 1m and 25.97s).
#
# moons - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 198!
# Done (0h 1m and 21.16s).
#
# moons - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 4 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 199!
# Done (0h 1m and 22.58s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0, 0.25]
# Doing experiment 201!
# Done (0h 1m and 34.25s).
#
# Not doing this.
# moons - imputation method: imputation missing_data_handling: mean imbalance: 0.25 pattern: 5 ratio_missing:None ratio_per_class: [0.1, 0.3]
# Doing experiment 202!
