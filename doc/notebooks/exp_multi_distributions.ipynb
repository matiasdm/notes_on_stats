# %% [markdown]
# # Development notebook. No experiments or results here. For dev purposes

# %%
run init.ipynb
# Out:
# Done.

# %% [markdown]
# # Experiment on the best imputation technics in the case of single disribution in the bayesian framework

# %%
"""  Fix parameters """

#Dataset default parameters
num_samples = 10000#NUM_SAMPLES

# pdf estimation default parameters
resolution = RESOLUTION
bandwidth = BANDWIDTH

# Classification default parameters
proportion_train = PROPORTION_TRAIN

# Verbosity
verbosity=0


"""  Parameters of the experiment """



range_dataset_name = ['circles', 'moons']




range_ratio_of_missing_values = [0., 0.1, 0.2, 0.3]
range_ratio_missing_per_class = [[0,0.25], [0.1, 0.3]]
range_imbalance_ratio = [0.1, 0.25, 0.5]
range_missingness_pattern = [1, 2, 3, 4, 5]
approach = 'multi_distributions'
missing_data_handling = 'without'
imputation_method = 'without'
df = create_df()
print("Approach is multi distributions (bayesian framework) with imputations of the missing values!\n\n\n")
start_total_time = time()
for dataset_name in range_dataset_name:
    for imbalance_ratio in range_imbalance_ratio:
        for missingness_pattern in range_missingness_pattern:

            if missingness_pattern in [1, 2, 3]:
                for ratio_of_missing_values in range_ratio_of_missing_values:
                    if len(df.query( " `dataset_name`==@dataset_name & `approach` == @approach & `imputation_method` == @imputation_method & `missing_data_handling` == @missing_data_handling & `ratio_of_missing_values`==@ratio_of_missing_values & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :
                        continue


                    try:
                        #if not len(df.query( " `dataset_name`==@dataset_name & `ratio_of_missing_values`==@ratio_of_missing_values & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :

                        print("{} - imputation method: {} imbalance: {} pattern: {} ratio :{}".format(dataset_name, 
                                                                                                      imputation_method, 
                                                                                                      imbalance_ratio,
                                                                                                      missingness_pattern,
                                                                                                      ratio_of_missing_values))

                        start_time = time()

                        dataset = DatasetGenerator(dataset_name=dataset_name, 
                                                num_samples=num_samples, 
                                                imbalance_ratio=imbalance_ratio, 
                                                missing_data_handling=missing_data_handling,
                                                imputation_method=imputation_method,
                                                verbosity=verbosity)

                        # Creation of the missingness
                        dataset.generate_missing_coordinates(missingness_pattern=missingness_pattern, ratio_of_missing_values=ratio_of_missing_values, ratio_missing_per_class=None)

                        dataset.split_test_train()

                        # Create the experiments
                        exp = Experiments(dataset_name, 
                                          dataset=dataset, 
                                          purpose='classification', 
                                          approach = approach, 
                                          previous_experiment=None, 
                                          save_experiment=True, 
                                          verbosity=verbosity, 
                                          debug=False, 
                                          proportion_train=PROPORTION_TRAIN, 
                                          resolution=RESOLUTION, 
                                          bandwidth=BANDWIDTH,
                                          random_state=RANDOM_STATE)


                        # Estimate the distributions 
                        exp.fit()

                        # Estimate the distributions 
                        exp.predict()

                        # Plot results
                        #exp.plot()


                        end_time = time()

                        hours, rest = divmod(end_time - start_time, 3600)
                        minutes, seconds = divmod(rest, 60)
                        print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
                    except:
                        print("/!\. Error!\n")

            elif missingness_pattern in [4, 5]:
                for ratio_missing_per_class in range_ratio_missing_per_class:
                    if len(df.query( " `dataset_name`==@dataset_name & `approach` == @approach & `imputation_method` == @imputation_method & `missing_data_handling` == @missing_data_handling & `ratio_missing_per_class_0`==@ratio_missing_per_class[0] & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :
                        continue




                    try:
                        #if not len(df.query( " `dataset_name`==@dataset_name & `ratio_of_missing_values`==@ratio_of_missing_values & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :

                        print("{} - imputation method: {} imbalance: {} pattern: {} ratio per class: {}".format(dataset_name, 
                                                                                                                          imputation_method, 
                                                                                                                          imbalance_ratio,
                                                                                                                          missingness_pattern,
                                                                                                                          str(ratio_missing_per_class)))

                        start_time = time()

                        dataset = DatasetGenerator(dataset_name=dataset_name, 
                                                num_samples=num_samples, 
                                                imbalance_ratio=imbalance_ratio, 
                                                missing_data_handling=missing_data_handling,
                                                imputation_method=imputation_method,
                                                verbosity=verbosity)

                        # Creation of the missingness
                        dataset.generate_missing_coordinates(missingness_pattern=missingness_pattern, ratio_of_missing_values=None, ratio_missing_per_class=ratio_missing_per_class)

                        dataset.split_test_train()

                        # Create the experiments
                        exp = Experiments(dataset_name, 
                                          dataset=dataset, 
                                          purpose='classification', 
                                          approach = approach, 
                                          previous_experiment=None, 
                                          save_experiment=True, 
                                          verbosity=verbosity, 
                                          debug=False, 
                                          proportion_train=PROPORTION_TRAIN, 
                                          resolution=RESOLUTION, 
                                          bandwidth=BANDWIDTH,
                                          random_state=RANDOM_STATE)


                        # Estimate the distributions 
                        exp.fit()

                        # Estimate the distributions 
                        exp.predict()

                        # Plot results
                        #exp.plot()


                        end_time = time()

                        hours, rest = divmod(end_time - start_time, 3600)
                        minutes, seconds = divmod(rest, 60)
                        print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
                    except:
                        print("/!\. Error!\n")

end_total_time = time()

hours, rest = divmod(end_total_time - start_total_time, 3600)
minutes, seconds = divmod(rest, 60)
print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
# Out:
# Approach is multi distributions (bayesian framework) with imputations of the missing values!
#
#
#
# circles - imputation method: without imbalance: 0.1 pattern: 1 ratio :0.0
# Doing experiment 77!
# Done (0h 4m and 16.54s).
#
# circles - imputation method: without imbalance: 0.1 pattern: 1 ratio :0.1
# Doing experiment 79!
# Done (0h 3m and 12.38s).
#
# circles - imputation method: without imbalance: 0.1 pattern: 1 ratio :0.2
# Doing experiment 81!
# Done (0h 3m and 19.99s).
#
# circles - imputation method: without imbalance: 0.1 pattern: 1 ratio :0.3
# Doing experiment 82!
# Done (0h 2m and 20.15s).
#
# circles - imputation method: without imbalance: 0.1 pattern: 2 ratio :0.0
# Doing experiment 83!
# Done (0h 2m and 27.62s).
#
# circles - imputation method: without imbalance: 0.1 pattern: 2 ratio :0.1
# Doing experiment 84!
# Done (0h 2m and 23.33s).
#
# circles - imputation method: without imbalance: 0.1 pattern: 2 ratio :0.2
# Doing experiment 85!
# Done (0h 1m and 56.18s).
#
# circles - imputation method: without imbalance: 0.1 pattern: 2 ratio :0.3
# Doing experiment 86!
# Done (0h 2m and 0.38s).
#
# circles - imputation method: without imbalance: 0.1 pattern: 3 ratio :0.0
# Doing experiment 89!
# Done (0h 2m and 18.30s).
#
# circles - imputation method: without imbalance: 0.1 pattern: 3 ratio :0.1
# Doing experiment 90!
# Done (0h 2m and 15.71s).
#
# circles - imputation method: without imbalance: 0.1 pattern: 3 ratio :0.2
# Doing experiment 91!
# Done (0h 2m and 45.76s).
#
# circles - imputation method: without imbalance: 0.1 pattern: 3 ratio :0.3
# Doing experiment 92!
# Done (0h 2m and 41.23s).
#
# circles - imputation method: without imbalance: 0.1 pattern: 4 ratio per class: [0, 0.25]
# Doing experiment 93!
# Done (0h 2m and 34.69s).
#
# circles - imputation method: without imbalance: 0.1 pattern: 4 ratio per class: [0.1, 0.3]
# Doing experiment 94!
# Done (0h 1m and 46.39s).
#
# circles - imputation method: without imbalance: 0.1 pattern: 5 ratio per class: [0, 0.25]
# Doing experiment 96!
# Done (0h 2m and 43.38s).
#
# circles - imputation method: without imbalance: 0.1 pattern: 5 ratio per class: [0.1, 0.3]
# Doing experiment 98!
# /!\. Error!
#
# circles - imputation method: without imbalance: 0.25 pattern: 1 ratio :0.0
# Doing experiment 99!
# Done (0h 2m and 51.03s).
#
# circles - imputation method: without imbalance: 0.25 pattern: 1 ratio :0.1
# Doing experiment 100!
# Done (0h 2m and 53.95s).
#
# circles - imputation method: without imbalance: 0.25 pattern: 1 ratio :0.2
# Doing experiment 101!
# Done (0h 2m and 41.36s).
#
# circles - imputation method: without imbalance: 0.25 pattern: 1 ratio :0.3
# Doing experiment 103!
# Done (0h 2m and 49.49s).
#
# circles - imputation method: without imbalance: 0.25 pattern: 2 ratio :0.0
# Doing experiment 104!
# Done (0h 2m and 46.80s).
#
# circles - imputation method: without imbalance: 0.25 pattern: 2 ratio :0.1
# Doing experiment 105!
# Done (0h 2m and 40.78s).
#
# circles - imputation method: without imbalance: 0.25 pattern: 2 ratio :0.2
# Doing experiment 107!
# Done (0h 2m and 34.79s).
#
# circles - imputation method: without imbalance: 0.25 pattern: 2 ratio :0.3
# Doing experiment 109!
# Done (0h 2m and 24.97s).
#
# circles - imputation method: without imbalance: 0.25 pattern: 3 ratio :0.0
# Doing experiment 110!
# Done (0h 2m and 47.74s).
#
# circles - imputation method: without imbalance: 0.25 pattern: 3 ratio :0.1
# Doing experiment 111!
# Done (0h 2m and 47.74s).
#
# circles - imputation method: without imbalance: 0.25 pattern: 3 ratio :0.2
# Doing experiment 112!
# Done (0h 2m and 42.23s).
#
# circles - imputation method: without imbalance: 0.25 pattern: 3 ratio :0.3
# Doing experiment 113!
# Done (0h 2m and 37.64s).
#
# circles - imputation method: without imbalance: 0.25 pattern: 4 ratio per class: [0, 0.25]
# Doing experiment 116!
# Done (0h 2m and 19.86s).
#
# circles - imputation method: without imbalance: 0.25 pattern: 4 ratio per class: [0.1, 0.3]
# Doing experiment 117!
# Done (0h 1m and 40.56s).
#
# circles - imputation method: without imbalance: 0.25 pattern: 5 ratio per class: [0, 0.25]
# Doing experiment 118!
# Done (0h 2m and 41.18s).
#
# circles - imputation method: without imbalance: 0.25 pattern: 5 ratio per class: [0.1, 0.3]
# Doing experiment 119!
# Done (0h 2m and 44.66s).
#
# circles - imputation method: without imbalance: 0.5 pattern: 1 ratio :0.0
# Doing experiment 120!
# Done (0h 2m and 47.95s).
#
# circles - imputation method: without imbalance: 0.5 pattern: 1 ratio :0.1
# Doing experiment 122!
# /!\. Error!
#
# circles - imputation method: without imbalance: 0.5 pattern: 1 ratio :0.2
# Doing experiment 123!
# /!\. Error!
#
# circles - imputation method: without imbalance: 0.5 pattern: 1 ratio :0.3
# Doing experiment 124!
# /!\. Error!
#
# circles - imputation method: without imbalance: 0.5 pattern: 2 ratio :0.0
# Doing experiment 126!
# Done (0h 2m and 49.67s).
#
# circles - imputation method: without imbalance: 0.5 pattern: 2 ratio :0.1
# Doing experiment 127!
# Done (0h 2m and 45.94s).
#
# circles - imputation method: without imbalance: 0.5 pattern: 2 ratio :0.2
# Doing experiment 129!
# Done (0h 2m and 33.55s).
#
# circles - imputation method: without imbalance: 0.5 pattern: 2 ratio :0.3
# Doing experiment 130!
# Done (0h 2m and 22.56s).
#
# circles - imputation method: without imbalance: 0.5 pattern: 3 ratio :0.0
# Doing experiment 131!
# Done (0h 2m and 46.72s).
#
# circles - imputation method: without imbalance: 0.5 pattern: 3 ratio :0.1
# Doing experiment 132!
# Done (0h 2m and 50.34s).
#
# circles - imputation method: without imbalance: 0.5 pattern: 3 ratio :0.2
# Doing experiment 134!
# Done (0h 2m and 42.35s).
#
# circles - imputation method: without imbalance: 0.5 pattern: 3 ratio :0.3
# Doing experiment 136!
# Done (0h 2m and 46.28s).
#
# circles - imputation method: without imbalance: 0.5 pattern: 4 ratio per class: [0, 0.25]
# Doing experiment 137!
# /!\. Error!
#
# circles - imputation method: without imbalance: 0.5 pattern: 4 ratio per class: [0.1, 0.3]
# Doing experiment 138!
# Done (0h 1m and 28.03s).
#
# circles - imputation method: without imbalance: 0.5 pattern: 5 ratio per class: [0, 0.25]
# Doing experiment 139!
# Done (0h 2m and 42.27s).
#
# circles - imputation method: without imbalance: 0.5 pattern: 5 ratio per class: [0.1, 0.3]
# Doing experiment 140!
# Done (0h 2m and 41.79s).
#
# moons - imputation method: without imbalance: 0.1 pattern: 1 ratio :0.0
# Doing experiment 1!
# Done (0h 2m and 48.83s).
#
# moons - imputation method: without imbalance: 0.1 pattern: 1 ratio :0.1
# Doing experiment 2!
# Done (0h 2m and 54.13s).
#
# moons - imputation method: without imbalance: 0.1 pattern: 1 ratio :0.2
# Doing experiment 3!
# Done (0h 2m and 41.53s).
#
# moons - imputation method: without imbalance: 0.1 pattern: 1 ratio :0.3
# Doing experiment 4!
# Done (0h 2m and 41.76s).
#
# moons - imputation method: without imbalance: 0.1 pattern: 2 ratio :0.0
# Doing experiment 5!
# Done (0h 2m and 58.28s).
#
# moons - imputation method: without imbalance: 0.1 pattern: 2 ratio :0.1
# Doing experiment 6!
# Done (0h 2m and 54.73s).
#
# moons - imputation method: without imbalance: 0.1 pattern: 2 ratio :0.2
# Doing experiment 7!
# Done (0h 2m and 51.96s).
#
# moons - imputation method: without imbalance: 0.1 pattern: 2 ratio :0.3
# Doing experiment 8!
# Done (0h 2m and 58.01s).
#
# moons - imputation method: without imbalance: 0.1 pattern: 3 ratio :0.0
# Doing experiment 9!
# Done (0h 3m and 36.59s).
#
# moons - imputation method: without imbalance: 0.1 pattern: 3 ratio :0.1
# Doing experiment 10!
# Done (0h 2m and 51.96s).
#
# moons - imputation method: without imbalance: 0.1 pattern: 3 ratio :0.2
# Doing experiment 11!
# Done (0h 2m and 50.93s).
#
# moons - imputation method: without imbalance: 0.1 pattern: 3 ratio :0.3
# Doing experiment 12!
# Done (0h 2m and 39.28s).
#
# moons - imputation method: without imbalance: 0.1 pattern: 4 ratio per class: [0, 0.25]
# Doing experiment 13!
# Done (0h 2m and 40.20s).
#
# moons - imputation method: without imbalance: 0.1 pattern: 4 ratio per class: [0.1, 0.3]
# Doing experiment 14!
# Done (0h 1m and 47.94s).
#
# moons - imputation method: without imbalance: 0.1 pattern: 5 ratio per class: [0, 0.25]
# Doing experiment 15!
# /!\. Error!
#
# moons - imputation method: without imbalance: 0.1 pattern: 5 ratio per class: [0.1, 0.3]
# Doing experiment 16!
# /!\. Error!
#
# moons - imputation method: without imbalance: 0.25 pattern: 1 ratio :0.0
# Doing experiment 17!
# Done (0h 2m and 49.93s).
#
# moons - imputation method: without imbalance: 0.25 pattern: 1 ratio :0.1
# Doing experiment 18!
# Done (0h 2m and 50.56s).
#
# moons - imputation method: without imbalance: 0.25 pattern: 1 ratio :0.2
# Doing experiment 19!
# Done (0h 2m and 47.14s).
#
# moons - imputation method: without imbalance: 0.25 pattern: 1 ratio :0.3
# Doing experiment 20!
# Done (0h 2m and 51.01s).
#
# moons - imputation method: without imbalance: 0.25 pattern: 2 ratio :0.0
# Doing experiment 21!
# Done (0h 2m and 55.41s).
#
# moons - imputation method: without imbalance: 0.25 pattern: 2 ratio :0.1
# Doing experiment 22!
# Done (0h 2m and 53.55s).
#
# moons - imputation method: without imbalance: 0.25 pattern: 2 ratio :0.2
# Doing experiment 23!
# Done (0h 2m and 42.04s).
#
# moons - imputation method: without imbalance: 0.25 pattern: 2 ratio :0.3
# Doing experiment 24!
# Done (0h 2m and 28.62s).
#
# moons - imputation method: without imbalance: 0.25 pattern: 3 ratio :0.0
# Doing experiment 25!
# Done (0h 2m and 48.64s).
#
# moons - imputation method: without imbalance: 0.25 pattern: 3 ratio :0.1
# Doing experiment 26!
# Done (0h 2m and 55.73s).
#
# moons - imputation method: without imbalance: 0.25 pattern: 3 ratio :0.2
# Doing experiment 27!
# Done (0h 2m and 53.44s).
#
# moons - imputation method: without imbalance: 0.25 pattern: 3 ratio :0.3
# Doing experiment 28!
# Done (0h 2m and 54.69s).
#
# moons - imputation method: without imbalance: 0.25 pattern: 4 ratio per class: [0, 0.25]
# Doing experiment 29!
# Done (0h 2m and 22.58s).
#
# moons - imputation method: without imbalance: 0.25 pattern: 4 ratio per class: [0.1, 0.3]
# Doing experiment 30!
# Done (0h 1m and 43.65s).
#
# moons - imputation method: without imbalance: 0.25 pattern: 5 ratio per class: [0, 0.25]
# Doing experiment 31!
# Done (0h 2m and 56.46s).
#
# moons - imputation method: without imbalance: 0.25 pattern: 5 ratio per class: [0.1, 0.3]
# Doing experiment 32!
# Done (0h 2m and 55.56s).
#
# moons - imputation method: without imbalance: 0.5 pattern: 1 ratio :0.0
# Doing experiment 33!
# Done (0h 2m and 55.26s).
#
# moons - imputation method: without imbalance: 0.5 pattern: 1 ratio :0.1
# Doing experiment 34!
# Done (0h 2m and 51.44s).
#
# moons - imputation method: without imbalance: 0.5 pattern: 1 ratio :0.2
# Doing experiment 35!
# Done (0h 2m and 54.83s).
#
# moons - imputation method: without imbalance: 0.5 pattern: 1 ratio :0.3
# Doing experiment 36!
# Done (0h 2m and 49.32s).
#
# moons - imputation method: without imbalance: 0.5 pattern: 2 ratio :0.0
# Doing experiment 37!
# Done (0h 2m and 53.29s).
#
# moons - imputation method: without imbalance: 0.5 pattern: 2 ratio :0.1
# Doing experiment 38!
# Done (0h 2m and 51.79s).
#
# moons - imputation method: without imbalance: 0.5 pattern: 2 ratio :0.2
# Doing experiment 39!
# Done (0h 2m and 42.50s).
#
# moons - imputation method: without imbalance: 0.5 pattern: 2 ratio :0.3
# Doing experiment 40!
# Done (0h 2m and 29.12s).
#
# moons - imputation method: without imbalance: 0.5 pattern: 3 ratio :0.0
# Doing experiment 41!
# Done (0h 2m and 53.41s).
#
# moons - imputation method: without imbalance: 0.5 pattern: 3 ratio :0.1
# Doing experiment 42!
# Done (0h 2m and 41.58s).
#
# moons - imputation method: without imbalance: 0.5 pattern: 3 ratio :0.2
# Doing experiment 43!
# Done (0h 2m and 55.58s).
#
# moons - imputation method: without imbalance: 0.5 pattern: 3 ratio :0.3
# Doing experiment 44!
# Done (0h 3m and 3.52s).
#
# moons - imputation method: without imbalance: 0.5 pattern: 4 ratio per class: [0, 0.25]
# Doing experiment 45!
# Done (0h 1m and 11.16s).
#
# moons - imputation method: without imbalance: 0.5 pattern: 4 ratio per class: [0.1, 0.3]
# Doing experiment 46!
# Done (0h 0m and 53.03s).
#
# moons - imputation method: without imbalance: 0.5 pattern: 5 ratio per class: [0, 0.25]
# Doing experiment 47!
# Done (0h 1m and 38.33s).
#
# moons - imputation method: without imbalance: 0.5 pattern: 5 ratio per class: [0.1, 0.3]
# Doing experiment 48!
# /!\. Error!
#
# Done (4h 13m and 2.66s).
