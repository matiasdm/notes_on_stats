# %% [markdown]
# # Experiment on the encoding and imputing technics for the Nam network, with and without Z !

# %%
run init.ipynb
# Out:
# Done.

# %%
from const import *

# %%
"""  Fix parameters """
RESOLUTION =30
BANDWIDTH = .2
#Dataset default parameters
num_samples = NUM_SAMPLES

# pdf estimation default parameters
resolution = RESOLUTION
bandwidth = BANDWIDTH

# Classification default parameters
proportion_train = PROPORTION_TRAIN

# Verbosity
verbosity=0


"""  Parameters of the experiment """



range_dataset_name = ['circles', 'moons']
range_use_missing_indicator_variables = [True, False]
range_missing_data_handling = ['encoding'] #TODO THIS IS WHERE WE SHOULD DO IMUTING BASED ON THE  OTHER EXPERIMENT


range_ratio_of_missing_values = [0., 0.25, 0.5]
range_ratio_missing_per_class = [[0,0.25], [0.1, 0.3]]
range_imbalance_ratio = [0.05, 0.25, 0.5]
range_missingness_pattern = [1, 3, 4, 5]
approach = 'nam'
imputation_method=None


print("Approach is Neural Additive Model with encoding of the missing values with or without the indicator variables!\n\n\n")
start_total_time = time()

for dataset_name in range_dataset_name:
    for missing_data_handling in range_missing_data_handling:
        for use_missing_indicator_variables in range_use_missing_indicator_variables:
            for imbalance_ratio in range_imbalance_ratio:
                for missingness_pattern in range_missingness_pattern:

                    if missingness_pattern in [1, 2, 3]:
                        for ratio_of_missing_values in range_ratio_of_missing_values:


                            try:
                                #if not len(df.query( " `dataset_name`==@dataset_name & `ratio_of_missing_values`==@ratio_of_missing_values & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :

                                print("{} - use_missing_indicator_variables: {} imbalance: {} pattern: {} ratio :{}".format(dataset_name, 
                                                                                                                                  use_missing_indicator_variables, 
                                                                                                                                  imbalance_ratio,
                                                                                                                                  missingness_pattern,
                                                                                                                                  ratio_of_missing_values))

                                start_time = time()

                                dataset = DatasetGenerator(dataset_name=dataset_name, 
                                                        num_samples=num_samples, 
                                                        imbalance_ratio=imbalance_ratio, 
                                                        missing_data_handling=missing_data_handling,
                                                        imputation_method=imputation_method,
                                                        verbosity=verbosity)

                                # Creation of the missingness
                                dataset.generate_missing_coordinates(missingness_pattern=missingness_pattern, ratio_of_missing_values=ratio_of_missing_values, ratio_missing_per_class=None)

                                dataset.split_test_train()

                                # Change dataset missing data handling
                                dataset.change_imputation_approach(missing_data_handling=missing_data_handling, imputation_method=imputation_method)

                                # Create the experiments
                                exp = Experiments(dataset_name, 
                                                  dataset=dataset, 
                                                  purpose='classification', 
                                                  approach = approach, 
                                                  previous_experiment=None, 
                                                  save_experiment=True, 
                                                  verbosity=verbosity, 
                                                  debug=False, 
                                                  proportion_train=PROPORTION_TRAIN, 
                                                  resolution=RESOLUTION, 
                                                  bandwidth=BANDWIDTH,
                                                  random_state=RANDOM_STATE)


                                # Estimate the distributions 
                                exp.fit(use_missing_indicator_variables=use_missing_indicator_variables)

                                # Estimate the distributions 
                                exp.predict()

                                end_time = time()

                                hours, rest = divmod(end_time - start_time, 3600)
                                minutes, seconds = divmod(rest, 60)
                                print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
                            except:
                                print("/!\. Error!\n")

                    elif missingness_pattern in [4, 5]:
                        for ratio_missing_per_class in range_ratio_missing_per_class:




                            try:
                                #if not len(df.query( " `dataset_name`==@dataset_name & `ratio_of_missing_values`==@ratio_of_missing_values & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :

                                print("{} - use_missing_indicator_variables: {} imbalance: {} pattern: {} ratio :{}".format(dataset_name, 
                                                                                                                                  use_missing_indicator_variables, 
                                                                                                                                  imbalance_ratio,
                                                                                                                                  missingness_pattern,
                                                                                                                                  str(ratio_missing_per_class)))

                                start_time = time()

                                dataset = DatasetGenerator(dataset_name=dataset_name, 
                                                        num_samples=num_samples, 
                                                        imbalance_ratio=imbalance_ratio, 
                                                        missing_data_handling=missing_data_handling,
                                                        imputation_method=imputation_method,
                                                        verbosity=verbosity)

                                # Creation of the missingness
                                dataset.generate_missing_coordinates(missingness_pattern=missingness_pattern, ratio_of_missing_values=None, ratio_missing_per_class=ratio_missing_per_class)

                                dataset.split_test_train()

                                # Create the experiments
                                exp = Experiments(dataset_name, 
                                                  dataset=dataset, 
                                                  purpose='classification', 
                                                  approach = approach, 
                                                  previous_experiment=None, 
                                                  save_experiment=True, 
                                                  verbosity=verbosity, 
                                                  debug=False, 
                                                  proportion_train=PROPORTION_TRAIN, 
                                                  resolution=RESOLUTION, 
                                                  bandwidth=BANDWIDTH,
                                                  random_state=RANDOM_STATE)


                                # Estimate the distributions 
                                exp.fit(use_missing_indicator_variables=use_missing_indicator_variables)

                                # Estimate the distributions 
                                exp.predict()


                                end_time = time()

                                hours, rest = divmod(end_time - start_time, 3600)
                                minutes, seconds = divmod(rest, 60)
                                print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
                            except:
                                print("/!\. Error!\n")

end_total_time = time()

hours, rest = divmod(end_total_time - start_total_time, 3600)
minutes, seconds = divmod(rest, 60)
print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
# Out:
# Approach is Neural Additive Model with encoding of the missing values with or without the indicator variables!
#
#
#
# circles - use_missing_indicator_variables: True imbalance: 0.05 pattern: 1 ratio :0.0
# Doing experiment 78!
# Done (0h 20m and 3.25s).
#
# circles - use_missing_indicator_variables: True imbalance: 0.05 pattern: 1 ratio :0.25
# Doing experiment 87!
# Done (0h 18m and 12.73s).
#
# circles - use_missing_indicator_variables: True imbalance: 0.05 pattern: 1 ratio :0.5
# Doing experiment 97!
# Done (0h 18m and 11.64s).
#
# circles - use_missing_indicator_variables: True imbalance: 0.05 pattern: 3 ratio :0.0
# Doing experiment 106!
# Done (0h 17m and 52.91s).
#
# circles - use_missing_indicator_variables: True imbalance: 0.05 pattern: 3 ratio :0.25
# Doing experiment 115!
# Done (0h 18m and 3.72s).
#
# circles - use_missing_indicator_variables: True imbalance: 0.05 pattern: 3 ratio :0.5
# Doing experiment 125!
# Done (0h 18m and 11.79s).
#
# circles - use_missing_indicator_variables: True imbalance: 0.05 pattern: 4 ratio :[0, 0.25]
# Doing experiment 133!
# Done (0h 18m and 13.79s).
#
# circles - use_missing_indicator_variables: True imbalance: 0.05 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 142!
# Done (0h 18m and 35.24s).
#
# circles - use_missing_indicator_variables: True imbalance: 0.05 pattern: 5 ratio :[0, 0.25]
# Doing experiment 144!
# Done (0h 20m and 14.73s).
#
# circles - use_missing_indicator_variables: True imbalance: 0.05 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 147!
# Done (0h 19m and 57.62s).
#
# circles - use_missing_indicator_variables: True imbalance: 0.25 pattern: 1 ratio :0.0
# Doing experiment 149!
# Done (0h 19m and 39.37s).
#
# circles - use_missing_indicator_variables: True imbalance: 0.25 pattern: 1 ratio :0.25
# Doing experiment 151!
# Done (0h 18m and 5.88s).
#
# circles - use_missing_indicator_variables: True imbalance: 0.25 pattern: 1 ratio :0.5
# Doing experiment 154!
# Done (0h 17m and 3.70s).
#
# circles - use_missing_indicator_variables: True imbalance: 0.25 pattern: 3 ratio :0.0
# Doing experiment 156!
# Done (0h 8m and 26.60s).
#
# circles - use_missing_indicator_variables: True imbalance: 0.25 pattern: 3 ratio :0.25
# Doing experiment 158!
# Done (0h 4m and 36.40s).
#
# circles - use_missing_indicator_variables: True imbalance: 0.25 pattern: 3 ratio :0.5
# Doing experiment 160!
# Done (0h 4m and 43.09s).
#
# circles - use_missing_indicator_variables: True imbalance: 0.25 pattern: 4 ratio :[0, 0.25]
# Doing experiment 162!
# /!\. Error!
#
# circles - use_missing_indicator_variables: True imbalance: 0.25 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: True imbalance: 0.25 pattern: 5 ratio :[0, 0.25]
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: True imbalance: 0.25 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: True imbalance: 0.5 pattern: 1 ratio :0.0
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: True imbalance: 0.5 pattern: 1 ratio :0.25
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: True imbalance: 0.5 pattern: 1 ratio :0.5
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: True imbalance: 0.5 pattern: 3 ratio :0.0
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: True imbalance: 0.5 pattern: 3 ratio :0.25
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: True imbalance: 0.5 pattern: 3 ratio :0.5
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: True imbalance: 0.5 pattern: 4 ratio :[0, 0.25]
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: True imbalance: 0.5 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: True imbalance: 0.5 pattern: 5 ratio :[0, 0.25]
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: True imbalance: 0.5 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 1 ratio :0.0
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 1 ratio :0.25
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 1 ratio :0.5
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 3 ratio :0.0
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 3 ratio :0.25
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 3 ratio :0.5
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 4 ratio :[0, 0.25]
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 5 ratio :[0, 0.25]
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 1 ratio :0.0
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 1 ratio :0.25
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 1 ratio :0.5
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 3 ratio :0.0
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 3 ratio :0.25
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 3 ratio :0.5
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 4 ratio :[0, 0.25]
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 5 ratio :[0, 0.25]
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 1 ratio :0.0
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 1 ratio :0.25
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 1 ratio :0.5
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 3 ratio :0.0
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 3 ratio :0.25
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 3 ratio :0.5
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 4 ratio :[0, 0.25]
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 5 ratio :[0, 0.25]
# Doing experiment 163!
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 163!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.05 pattern: 1 ratio :0.0
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.05 pattern: 1 ratio :0.25
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.05 pattern: 1 ratio :0.5
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.05 pattern: 3 ratio :0.0
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.05 pattern: 3 ratio :0.25
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.05 pattern: 3 ratio :0.5
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.05 pattern: 4 ratio :[0, 0.25]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.05 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.05 pattern: 5 ratio :[0, 0.25]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.05 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.25 pattern: 1 ratio :0.0
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.25 pattern: 1 ratio :0.25
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.25 pattern: 1 ratio :0.5
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.25 pattern: 3 ratio :0.0
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.25 pattern: 3 ratio :0.25
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.25 pattern: 3 ratio :0.5
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.25 pattern: 4 ratio :[0, 0.25]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.25 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.25 pattern: 5 ratio :[0, 0.25]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.25 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.5 pattern: 1 ratio :0.0
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.5 pattern: 1 ratio :0.25
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.5 pattern: 1 ratio :0.5
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.5 pattern: 3 ratio :0.0
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.5 pattern: 3 ratio :0.25
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.5 pattern: 3 ratio :0.5
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.5 pattern: 4 ratio :[0, 0.25]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.5 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.5 pattern: 5 ratio :[0, 0.25]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: True imbalance: 0.5 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 1 ratio :0.0
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 1 ratio :0.25
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 1 ratio :0.5
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 3 ratio :0.0
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 3 ratio :0.25
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 3 ratio :0.5
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 4 ratio :[0, 0.25]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 5 ratio :[0, 0.25]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 1 ratio :0.0
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 1 ratio :0.25
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 1 ratio :0.5
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 3 ratio :0.0
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 3 ratio :0.25
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 3 ratio :0.5
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 4 ratio :[0, 0.25]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 5 ratio :[0, 0.25]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 1 ratio :0.0
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 1 ratio :0.25
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 1 ratio :0.5
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 3 ratio :0.0
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 3 ratio :0.25
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 3 ratio :0.5
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 4 ratio :[0, 0.25]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 5 ratio :[0, 0.25]
# Doing experiment 49!
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 49!
# /!\. Error!
#
# Done (4h 20m and 48.20s).

# %%
"""  Fix parameters """

#Dataset default parameters
num_samples = NUM_SAMPLES

# pdf estimation default parameters
resolution = RESOLUTION
bandwidth = BANDWIDTH

# Classification default parameters
proportion_train = PROPORTION_TRAIN

# Verbosity
verbosity=0


"""  Parameters of the experiment """



range_dataset_name = ['circles', 'moons']
range_use_missing_indicator_variables = [False]
range_missing_data_handling = ['encoding'] #TODO THIS IS WHERE WE SHOULD DO IMUTING BASED ON THE  OTHER EXPERIMENT


range_ratio_of_missing_values = [0., 0.25, 0.5]
range_ratio_missing_per_class = [[0,0.25], [0.1, 0.3]]
range_imbalance_ratio = [0.05, 0.25, 0.5]
range_missingness_pattern = [5, 1, 2, 3, 4,]
approach = 'nam'
imputation_method=None


print("Approach is Neural Additive Model with encoding of the missing values with or without the indicator variables!\n\n\n")
start_total_time = time()

for dataset_name in range_dataset_name:
    for missing_data_handling in range_missing_data_handling:
        for use_missing_indicator_variables in range_use_missing_indicator_variables:
            for imbalance_ratio in range_imbalance_ratio:
                for missingness_pattern in range_missingness_pattern:

                    if missingness_pattern in [1, 2, 3]:
                        for ratio_of_missing_values in range_ratio_of_missing_values:


                            try:
                                #if not len(df.query( " `dataset_name`==@dataset_name & `ratio_of_missing_values`==@ratio_of_missing_values & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :

                                print("{} - use_missing_indicator_variables: {} imbalance: {} pattern: {} ratio :{}".format(dataset_name, 
                                                                                                                                  use_missing_indicator_variables, 
                                                                                                                                  imbalance_ratio,
                                                                                                                                  missingness_pattern,
                                                                                                                                  ratio_of_missing_values))

                                start_time = time()

                                dataset = DatasetGenerator(dataset_name=dataset_name, 
                                                        num_samples=num_samples, 
                                                        imbalance_ratio=imbalance_ratio, 
                                                        missing_data_handling=missing_data_handling,
                                                        imputation_method=imputation_method,
                                                        verbosity=verbosity)

                                # Creation of the missingness
                                dataset.generate_missing_coordinates(missingness_pattern=missingness_pattern, ratio_of_missing_values=ratio_of_missing_values, ratio_missing_per_class=None)

                                dataset.split_test_train()

                                # Change dataset missing data handling
                                dataset.change_imputation_approach(missing_data_handling=missing_data_handling, imputation_method=imputation_method)

                                # Create the experiments
                                exp = Experiments(dataset_name, 
                                                  dataset=dataset, 
                                                  purpose='classification', 
                                                  approach = approach, 
                                                  previous_experiment=None, 
                                                  save_experiment=True, 
                                                  verbosity=verbosity, 
                                                  debug=False, 
                                                  proportion_train=PROPORTION_TRAIN, 
                                                  resolution=RESOLUTION, 
                                                  bandwidth=BANDWIDTH,
                                                  random_state=RANDOM_STATE)


                                # Estimate the distributions 
                                exp.fit(use_missing_indicator_variables=use_missing_indicator_variables)

                                # Estimate the distributions 
                                exp.predict()

                                end_time = time()

                                hours, rest = divmod(end_time - start_time, 3600)
                                minutes, seconds = divmod(rest, 60)
                                print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
                            except:
                                print("/!\. Error!\n")

                    elif missingness_pattern in [4, 5]:
                        for ratio_missing_per_class in range_ratio_missing_per_class:




                            try:
                                #if not len(df.query( " `dataset_name`==@dataset_name & `ratio_of_missing_values`==@ratio_of_missing_values & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :

                                print("{} - use_missing_indicator_variables: {} imbalance: {} pattern: {} ratio :{}".format(dataset_name, 
                                                                                                                                  use_missing_indicator_variables, 
                                                                                                                                  imbalance_ratio,
                                                                                                                                  missingness_pattern,
                                                                                                                                  str(ratio_missing_per_class)))

                                start_time = time()

                                dataset = DatasetGenerator(dataset_name=dataset_name, 
                                                        num_samples=num_samples, 
                                                        imbalance_ratio=imbalance_ratio, 
                                                        missing_data_handling=missing_data_handling,
                                                        imputation_method=imputation_method,
                                                        verbosity=verbosity)

                                # Creation of the missingness
                                dataset.generate_missing_coordinates(missingness_pattern=missingness_pattern, ratio_of_missing_values=None, ratio_missing_per_class=ratio_missing_per_class)

                                dataset.split_test_train()

                                # Create the experiments
                                exp = Experiments(dataset_name, 
                                                  dataset=dataset, 
                                                  purpose='classification', 
                                                  approach = approach, 
                                                  previous_experiment=None, 
                                                  save_experiment=True, 
                                                  verbosity=verbosity, 
                                                  debug=False, 
                                                  proportion_train=PROPORTION_TRAIN, 
                                                  resolution=RESOLUTION, 
                                                  bandwidth=BANDWIDTH,
                                                  random_state=RANDOM_STATE)


                                # Estimate the distributions 
                                exp.fit(use_missing_indicator_variables=use_missing_indicator_variables)

                                # Estimate the distributions 
                                exp.predict()


                                end_time = time()

                                hours, rest = divmod(end_time - start_time, 3600)
                                minutes, seconds = divmod(rest, 60)
                                print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
                            except:
                                print("/!\. Error!\n")

end_total_time = time()

hours, rest = divmod(end_total_time - start_total_time, 3600)
minutes, seconds = divmod(rest, 60)
print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
# Out:
# Approach is Neural Additive Model with encoding of the missing values with or without the indicator variables!
#
#
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 5 ratio :[0, 0.25]
# Doing experiment 182!
# Done (0h 2m and 49.77s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 184!
# Done (0h 2m and 50.38s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 1 ratio :0.0
# Doing experiment 186!
# Done (0h 2m and 47.42s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 1 ratio :0.25
# Doing experiment 188!
# Done (0h 2m and 50.28s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 1 ratio :0.5
# Doing experiment 190!
# Done (0h 2m and 53.17s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 2 ratio :0.0
# Doing experiment 192!
# Done (0h 2m and 49.81s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 2 ratio :0.25
# Doing experiment 194!
# Done (0h 2m and 43.06s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 2 ratio :0.5
# Doing experiment 196!
# Done (0h 2m and 50.62s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 3 ratio :0.0
# Doing experiment 198!
# Done (0h 2m and 46.60s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 3 ratio :0.25
# Doing experiment 200!
# Done (0h 2m and 44.19s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 3 ratio :0.5
# Doing experiment 202!
# Done (0h 2m and 48.99s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 4 ratio :[0, 0.25]
# Doing experiment 204!
# Done (0h 2m and 46.86s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.05 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 206!
# Done (0h 2m and 43.78s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 5 ratio :[0, 0.25]
# Doing experiment 208!
# Done (0h 2m and 41.58s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 210!
# Done (0h 2m and 44.34s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 1 ratio :0.0
# Doing experiment 212!
# Done (0h 2m and 45.39s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 1 ratio :0.25
# Doing experiment 214!
# Done (0h 2m and 44.96s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 1 ratio :0.5
# Doing experiment 216!
# Done (0h 2m and 41.77s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 2 ratio :0.0
# Doing experiment 217!
# Done (0h 2m and 43.10s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 2 ratio :0.25
# Doing experiment 219!
# Done (0h 2m and 43.71s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 2 ratio :0.5
# Doing experiment 221!
# Done (0h 2m and 53.99s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 3 ratio :0.0
# Doing experiment 223!
# Done (0h 2m and 44.69s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 3 ratio :0.25
# Doing experiment 225!
# Done (0h 2m and 43.32s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 3 ratio :0.5
# Doing experiment 227!
# Done (0h 2m and 54.06s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 4 ratio :[0, 0.25]
# Doing experiment 229!
# Done (0h 2m and 44.91s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.25 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 231!
# Done (0h 2m and 44.88s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 5 ratio :[0, 0.25]
# Doing experiment 233!
# Done (0h 2m and 44.22s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 235!
# Done (0h 2m and 43.56s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 1 ratio :0.0
# Doing experiment 237!
# Done (0h 2m and 45.66s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 1 ratio :0.25
# Doing experiment 239!
# Done (0h 2m and 43.25s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 1 ratio :0.5
# Doing experiment 241!
# Done (0h 2m and 40.91s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 2 ratio :0.0
# Doing experiment 243!
# Done (0h 2m and 43.29s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 2 ratio :0.25
# Doing experiment 245!
# Done (0h 2m and 43.85s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 2 ratio :0.5
# Doing experiment 247!
# Done (0h 2m and 42.69s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 3 ratio :0.0
# Doing experiment 249!
# Done (0h 2m and 45.17s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 3 ratio :0.25
# Doing experiment 251!
# Done (0h 2m and 44.28s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 3 ratio :0.5
# Doing experiment 253!
# Done (0h 2m and 43.49s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 4 ratio :[0, 0.25]
# Doing experiment 254!
# Done (0h 2m and 45.21s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.5 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 256!
# Done (0h 2m and 43.72s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 5 ratio :[0, 0.25]
# Doing experiment 1!
# Done (0h 2m and 47.95s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 2!
# Done (0h 2m and 45.03s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 1 ratio :0.0
# Doing experiment 3!
# Done (0h 2m and 43.73s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 1 ratio :0.25
# Doing experiment 4!
# Done (0h 2m and 45.97s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 1 ratio :0.5
# Doing experiment 5!
# Done (0h 2m and 45.85s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 2 ratio :0.0
# Doing experiment 6!
# Done (0h 2m and 45.13s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 2 ratio :0.25
# Doing experiment 8!
# Done (0h 2m and 8.27s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 2 ratio :0.5
# Doing experiment 11!
# Done (0h 2m and 4.71s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 3 ratio :0.0
# Doing experiment 12!
# Done (0h 2m and 5.71s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 3 ratio :0.25
# Doing experiment 13!
# Done (0h 2m and 6.46s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 3 ratio :0.5
# Doing experiment 14!
# Done (0h 2m and 8.17s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 4 ratio :[0, 0.25]
# Doing experiment 15!
# Done (0h 2m and 5.88s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.05 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 16!
# Done (0h 2m and 5.71s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 5 ratio :[0, 0.25]
# Doing experiment 17!
# Done (0h 2m and 6.14s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 18!
# Done (0h 2m and 4.79s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 1 ratio :0.0
# Doing experiment 19!
# Done (0h 2m and 3.92s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 1 ratio :0.25
# Doing experiment 20!
# Done (0h 2m and 7.33s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 1 ratio :0.5
# Doing experiment 21!
# Done (0h 2m and 5.83s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 2 ratio :0.0
# Doing experiment 22!
# Done (0h 2m and 9.10s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 2 ratio :0.25
# Doing experiment 23!
# Done (0h 2m and 12.39s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 2 ratio :0.5
# Doing experiment 24!
# Done (0h 2m and 17.43s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 3 ratio :0.0
# Doing experiment 25!
# Done (0h 2m and 10.44s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 3 ratio :0.25
# Doing experiment 26!
# Done (0h 2m and 16.73s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 3 ratio :0.5
# Doing experiment 27!
# Done (0h 2m and 11.42s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 4 ratio :[0, 0.25]
# Doing experiment 28!
# Done (0h 2m and 11.11s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.25 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 29!
# Done (0h 2m and 9.19s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 5 ratio :[0, 0.25]
# Doing experiment 30!
# Done (0h 2m and 11.06s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 31!
# Done (0h 2m and 6.91s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 1 ratio :0.0
# Doing experiment 33!
# Done (0h 2m and 9.41s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 1 ratio :0.25
# Doing experiment 37!
# Done (0h 13m and 30.21s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 1 ratio :0.5
# Doing experiment 42!
# Done (0h 23m and 12.53s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 2 ratio :0.0
# Doing experiment 47!
# Done (0h 2m and 7.09s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 2 ratio :0.25
# Doing experiment 51!
# Done (0h 2m and 6.11s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 2 ratio :0.5
# Doing experiment 56!
# Done (0h 2m and 10.84s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 3 ratio :0.0
# Doing experiment 60!
# Done (0h 2m and 8.15s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 3 ratio :0.25
# Doing experiment 65!
# Done (0h 2m and 6.89s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 3 ratio :0.5
# Doing experiment 69!
# Done (0h 2m and 6.77s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 4 ratio :[0, 0.25]
# Doing experiment 74!
# Done (0h 2m and 10.87s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.5 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 79!
# Done (0h 2m and 8.08s).
#
# Done (3h 47m and 24.26s).

# %%
#Dataset default parameters
num_samples = 10000#NUM_SAMPLES

# pdf estimation default parameters
resolution = RESOLUTION
bandwidth = BANDWIDTH

# Classification default parameters
proportion_train = PROPORTION_TRAIN

# Verbosity
verbosity=0


"""  Parameters of the experiment """



range_dataset_name = ['circles', 'moons']
range_use_missing_indicator_variables = [True]
range_missing_data_handling = ['encoding'] #TODO THIS IS WHERE WE SHOULD DO IMUTING BASED ON THE  OTHER EXPERIMENT


range_ratio_of_missing_values = [0, .1, 0.3]
range_ratio_missing_per_class = [[0,0.25], [0.1, 0.3]]
range_imbalance_ratio = [0.1, 0.25, 0.5]
range_missingness_pattern = [5, 1, 2, 3, 4]
approach = 'nam'
imputation_method=None

df = create_df()

# %%
"""  Fix parameters """

#Dataset default parameters
num_samples = 10000#NUM_SAMPLES

# pdf estimation default parameters
resolution = RESOLUTION
bandwidth = BANDWIDTH

# Classification default parameters
proportion_train = PROPORTION_TRAIN

# Verbosity
verbosity=0


"""  Parameters of the experiment """



range_dataset_name = ['circles', 'moons']
range_use_missing_indicator_variables = [False]
range_missing_data_handling = ['encoding'] #TODO THIS IS WHERE WE SHOULD DO IMUTING BASED ON THE  OTHER EXPERIMENT


range_ratio_of_missing_values = [.15, .3, 0.6]
range_ratio_missing_per_class = [[0,0.25], [0.1, 0.3]]
range_imbalance_ratio = [0.1]
range_missingness_pattern = [5, 1, 2, 3, 4,]
approach = 'nam'
imputation_method=None

df = create_df()
print("Approach is Neural Additive Model with encoding of the missing values with or without the indicator variables!\n\n\n")
start_total_time = time()

for dataset_name in range_dataset_name:
    for missing_data_handling in range_missing_data_handling:
        for use_missing_indicator_variables in range_use_missing_indicator_variables:
            for imbalance_ratio in range_imbalance_ratio:
                for missingness_pattern in range_missingness_pattern:

                    if missingness_pattern in [1, 2, 3]:
                        for ratio_of_missing_values in range_ratio_of_missing_values:
                            if len(df.query( " `dataset_name`==@dataset_name & `approach` == @approach & `use_missing_indicator_variables`==@use_missing_indicator_variables & `imputation_method` == @imputation_method & `missing_data_handling` == @missing_data_handling & `ratio_of_missing_values`==@ratio_of_missing_values & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :
                                continue

                            try:
                                #if not len(df.query( " `dataset_name`==@dataset_name & `ratio_of_missing_values`==@ratio_of_missing_values & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :

                                print("{} - use_missing_indicator_variables: {} imbalance: {} pattern: {} ratio :{}".format(dataset_name, 
                                                                                                                                  use_missing_indicator_variables, 
                                                                                                                                  imbalance_ratio,
                                                                                                                                  missingness_pattern,
                                                                                                                                  ratio_of_missing_values))

                                start_time = time()

                                dataset = DatasetGenerator(dataset_name=dataset_name, 
                                                        num_samples=num_samples, 
                                                        imbalance_ratio=imbalance_ratio, 
                                                        missing_data_handling=missing_data_handling,
                                                        imputation_method=imputation_method,
                                                        verbosity=verbosity)

                                # Creation of the missingness
                                dataset.generate_missing_coordinates(missingness_pattern=missingness_pattern, ratio_of_missing_values=ratio_of_missing_values, ratio_missing_per_class=None)

                                dataset.split_test_train()

                                # Change dataset missing data handling
                                dataset.change_imputation_approach(missing_data_handling=missing_data_handling, imputation_method=imputation_method)

                                # Create the experiments
                                exp = Experiments(dataset_name, 
                                                  dataset=dataset, 
                                                  purpose='classification', 
                                                  approach = approach, 
                                                  previous_experiment=None, 
                                                  save_experiment=True, 
                                                  verbosity=verbosity, 
                                                  debug=False, 
                                                  proportion_train=PROPORTION_TRAIN, 
                                                  resolution=RESOLUTION, 
                                                  bandwidth=BANDWIDTH,
                                                  random_state=RANDOM_STATE)


                                # Estimate the distributions 
                                exp.fit(use_missing_indicator_variables=use_missing_indicator_variables)

                                # Estimate the distributions 
                                exp.predict()

                                end_time = time()

                                hours, rest = divmod(end_time - start_time, 3600)
                                minutes, seconds = divmod(rest, 60)
                                print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
                            except:
                                print("/!\. Error!\n")

                    elif missingness_pattern in [4, 5]:
                        for ratio_missing_per_class in range_ratio_missing_per_class:
                            if len(df.query( " `dataset_name`==@dataset_name & `approach` == @approach & `use_missing_indicator_variables`==@use_missing_indicator_variables & `imputation_method` == @imputation_method & `missing_data_handling` == @missing_data_handling & `ratio_missing_per_class_0`==@ratio_missing_per_class[0] & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :
                                continue




                            try:
                                #if not len(df.query( " `dataset_name`==@dataset_name & `ratio_of_missing_values`==@ratio_of_missing_values & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :

                                print("{} - use_missing_indicator_variables: {} imbalance: {} pattern: {} ratio :{}".format(dataset_name, 
                                                                                                                                  use_missing_indicator_variables, 
                                                                                                                                  imbalance_ratio,
                                                                                                                                  missingness_pattern,
                                                                                                                                  str(ratio_missing_per_class)))

                                start_time = time()

                                dataset = DatasetGenerator(dataset_name=dataset_name, 
                                                        num_samples=num_samples, 
                                                        imbalance_ratio=imbalance_ratio, 
                                                        missing_data_handling=missing_data_handling,
                                                        imputation_method=imputation_method,
                                                        verbosity=verbosity)

                                # Creation of the missingness
                                dataset.generate_missing_coordinates(missingness_pattern=missingness_pattern, ratio_of_missing_values=None, ratio_missing_per_class=ratio_missing_per_class)

                                dataset.split_test_train()

                                # Create the experiments
                                exp = Experiments(dataset_name, 
                                                  dataset=dataset, 
                                                  purpose='classification', 
                                                  approach = approach, 
                                                  previous_experiment=None, 
                                                  save_experiment=True, 
                                                  verbosity=verbosity, 
                                                  debug=False, 
                                                  proportion_train=PROPORTION_TRAIN, 
                                                  resolution=RESOLUTION, 
                                                  bandwidth=BANDWIDTH,
                                                  random_state=RANDOM_STATE)


                                # Estimate the distributions 
                                exp.fit(use_missing_indicator_variables=use_missing_indicator_variables)

                                # Estimate the distributions 
                                exp.predict()


                                end_time = time()

                                hours, rest = divmod(end_time - start_time, 3600)
                                minutes, seconds = divmod(rest, 60)
                                print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
                            except:
                                print("/!\. Error!\n")

end_total_time = time()

hours, rest = divmod(end_total_time - start_total_time, 3600)
minutes, seconds = divmod(rest, 60)
print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
# Out:
# Approach is Neural Additive Model with encoding of the missing values with or without the indicator variables!
#
#
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 5 ratio :[0, 0.25]
# Doing experiment 304!
# Done (0h 4m and 58.96s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 305!
# Done (0h 4m and 57.03s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 1 ratio :0.15
# Doing experiment 307!
# Done (0h 5m and 24.16s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 1 ratio :0.3
# Doing experiment 309!
# Done (0h 5m and 2.13s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 1 ratio :0.6
# Doing experiment 310!
# Done (0h 5m and 42.00s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 2 ratio :0.15
# Doing experiment 312!
# Done (0h 5m and 15.20s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 2 ratio :0.3
# Doing experiment 314!
# Done (0h 7m and 35.02s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 2 ratio :0.6
# Doing experiment 316!
# Done (0h 7m and 41.49s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 3 ratio :0.15
# Doing experiment 317!
# Done (0h 6m and 15.56s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 3 ratio :0.3
# Doing experiment 319!
# Done (0h 6m and 7.55s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 3 ratio :0.6
# Doing experiment 320!
# Done (0h 5m and 9.42s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 4 ratio :[0, 0.25]
# Doing experiment 323!
# Done (0h 5m and 57.91s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 331!
# Done (0h 4m and 47.06s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 5 ratio :[0, 0.25]
# Doing experiment 89!
# Done (0h 4m and 36.99s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 92!
# Done (0h 4m and 35.94s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 1 ratio :0.15
# Doing experiment 93!
# Done (0h 4m and 28.11s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 1 ratio :0.3
# Doing experiment 94!
# Done (0h 4m and 33.86s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 1 ratio :0.6
# Doing experiment 95!
# Done (0h 4m and 23.70s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 2 ratio :0.15
# Doing experiment 96!
# Done (0h 4m and 21.52s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 2 ratio :0.3
# Doing experiment 97!
# Done (0h 4m and 20.73s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 2 ratio :0.6
# Doing experiment 98!
# Done (0h 4m and 23.26s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 3 ratio :0.15
# Doing experiment 99!
# Done (0h 4m and 10.66s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 3 ratio :0.3
# Doing experiment 100!
# Done (0h 4m and 12.63s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 3 ratio :0.6
# Doing experiment 101!
# Done (0h 4m and 14.80s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 4 ratio :[0, 0.25]
# Doing experiment 102!
# Done (0h 4m and 9.41s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 103!
# Done (0h 4m and 36.45s).
#
# Done (2h 12m and 1.90s).

# %%
#Dataset default parameters
num_samples = 10000#NUM_SAMPLES

# pdf estimation default parameters
resolution = RESOLUTION
bandwidth = BANDWIDTH

# Classification default parameters
proportion_train = PROPORTION_TRAIN

# Verbosity
verbosity=0


"""  Parameters of the experiment """



range_dataset_name = ['circles', 'moons']
range_use_missing_indicator_variables = [True]
range_missing_data_handling = ['imputing'] #TODO THIS IS WHERE WE SHOULD DO IMUTING BASED ON THE  OTHER EXPERIMENT


range_ratio_of_missing_values = [0, .1, 0.3]
range_ratio_missing_per_class = [[0,0.25], [0.1, 0.3]]
range_imbalance_ratio = [0.1, 0.25, 0.5]
range_missingness_pattern = [5, 1, 2, 3, 4]
approach = 'nam'
imputation_method='mice'

df = create_df()

# %%
"""  Fix parameters """

#Dataset default parameters
num_samples = 10000#NUM_SAMPLES

# pdf estimation default parameters
resolution = RESOLUTION
bandwidth = BANDWIDTH

# Classification default parameters
proportion_train = PROPORTION_TRAIN

# Verbosity
verbosity=0


"""  Parameters of the experiment """



range_dataset_name = ['circles', 'moons']
range_use_missing_indicator_variables = [False]
range_missing_data_handling = ['encoding'] #TODO THIS IS WHERE WE SHOULD DO IMUTING BASED ON THE  OTHER EXPERIMENT


range_ratio_of_missing_values = [.15, .3, 0.6]
range_ratio_missing_per_class = [[0,0.25], [0.1, 0.3]]
range_imbalance_ratio = [0.1]
range_missingness_pattern = [5, 1, 2, 3, 4,]
approach = 'nam'
imputation_method=None

df = create_df()
print("Approach is Neural Additive Model with encoding of the missing values with or without the indicator variables!\n\n\n")
start_total_time = time()

for dataset_name in range_dataset_name:
    for missing_data_handling in range_missing_data_handling:
        for use_missing_indicator_variables in range_use_missing_indicator_variables:
            for imbalance_ratio in range_imbalance_ratio:
                for missingness_pattern in range_missingness_pattern:

                    if missingness_pattern in [1, 2, 3]:
                        for ratio_of_missing_values in range_ratio_of_missing_values:
                            if len(df.query( " `dataset_name`==@dataset_name & `approach` == @approach & `use_missing_indicator_variables`==@use_missing_indicator_variables & `imputation_method` == @imputation_method & `missing_data_handling` == @missing_data_handling & `ratio_of_missing_values`==@ratio_of_missing_values & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :
                                continue

                            try:
                                #if not len(df.query( " `dataset_name`==@dataset_name & `ratio_of_missing_values`==@ratio_of_missing_values & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :

                                print("{} - use_missing_indicator_variables: {} imbalance: {} pattern: {} ratio :{}".format(dataset_name, 
                                                                                                                                  use_missing_indicator_variables, 
                                                                                                                                  imbalance_ratio,
                                                                                                                                  missingness_pattern,
                                                                                                                                  ratio_of_missing_values))

                                start_time = time()

                                dataset = DatasetGenerator(dataset_name=dataset_name, 
                                                        num_samples=num_samples, 
                                                        imbalance_ratio=imbalance_ratio, 
                                                        missing_data_handling=missing_data_handling,
                                                        imputation_method=imputation_method,
                                                        verbosity=verbosity)

                                # Creation of the missingness
                                dataset.generate_missing_coordinates(missingness_pattern=missingness_pattern, ratio_of_missing_values=ratio_of_missing_values, ratio_missing_per_class=None)

                                dataset.split_test_train()

                                # Change dataset missing data handling
                                dataset.change_imputation_approach(missing_data_handling=missing_data_handling, imputation_method=imputation_method)

                                # Create the experiments
                                exp = Experiments(dataset_name, 
                                                  dataset=dataset, 
                                                  purpose='classification', 
                                                  approach = approach, 
                                                  previous_experiment=None, 
                                                  save_experiment=True, 
                                                  verbosity=verbosity, 
                                                  debug=False, 
                                                  proportion_train=PROPORTION_TRAIN, 
                                                  resolution=RESOLUTION, 
                                                  bandwidth=BANDWIDTH,
                                                  random_state=RANDOM_STATE)


                                # Estimate the distributions 
                                exp.fit(use_missing_indicator_variables=use_missing_indicator_variables)

                                # Estimate the distributions 
                                exp.predict()

                                end_time = time()

                                hours, rest = divmod(end_time - start_time, 3600)
                                minutes, seconds = divmod(rest, 60)
                                print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
                            except:
                                print("/!\. Error!\n")

                    elif missingness_pattern in [4, 5]:
                        for ratio_missing_per_class in range_ratio_missing_per_class:
                            if len(df.query( " `dataset_name`==@dataset_name & `approach` == @approach & `use_missing_indicator_variables`==@use_missing_indicator_variables & `imputation_method` == @imputation_method & `missing_data_handling` == @missing_data_handling & `ratio_missing_per_class_0`==@ratio_missing_per_class[0] & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :
                                continue




                            try:
                                #if not len(df.query( " `dataset_name`==@dataset_name & `ratio_of_missing_values`==@ratio_of_missing_values & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :

                                print("{} - use_missing_indicator_variables: {} imbalance: {} pattern: {} ratio :{}".format(dataset_name, 
                                                                                                                                  use_missing_indicator_variables, 
                                                                                                                                  imbalance_ratio,
                                                                                                                                  missingness_pattern,
                                                                                                                                  str(ratio_missing_per_class)))

                                start_time = time()

                                dataset = DatasetGenerator(dataset_name=dataset_name, 
                                                        num_samples=num_samples, 
                                                        imbalance_ratio=imbalance_ratio, 
                                                        missing_data_handling=missing_data_handling,
                                                        imputation_method=imputation_method,
                                                        verbosity=verbosity)

                                # Creation of the missingness
                                dataset.generate_missing_coordinates(missingness_pattern=missingness_pattern, ratio_of_missing_values=None, ratio_missing_per_class=ratio_missing_per_class)

                                dataset.split_test_train()

                                # Create the experiments
                                exp = Experiments(dataset_name, 
                                                  dataset=dataset, 
                                                  purpose='classification', 
                                                  approach = approach, 
                                                  previous_experiment=None, 
                                                  save_experiment=True, 
                                                  verbosity=verbosity, 
                                                  debug=False, 
                                                  proportion_train=PROPORTION_TRAIN, 
                                                  resolution=RESOLUTION, 
                                                  bandwidth=BANDWIDTH,
                                                  random_state=RANDOM_STATE)


                                # Estimate the distributions 
                                exp.fit(use_missing_indicator_variables=use_missing_indicator_variables)

                                # Estimate the distributions 
                                exp.predict()


                                end_time = time()

                                hours, rest = divmod(end_time - start_time, 3600)
                                minutes, seconds = divmod(rest, 60)
                                print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
                            except:
                                print("/!\. Error!\n")

end_total_time = time()

hours, rest = divmod(end_total_time - start_total_time, 3600)
minutes, seconds = divmod(rest, 60)
print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
# Out:
# Approach is Neural Additive Model with encoding of the missing values with or without the indicator variables!
#
#
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 5 ratio :[0, 0.25]
# Doing experiment 343!
# Done (0h 5m and 0.97s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 347!
# Done (0h 5m and 16.29s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 1 ratio :0.15
# Doing experiment 353!
# Done (0h 4m and 53.95s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 1 ratio :0.3
# Doing experiment 358!
# Done (0h 5m and 11.36s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 1 ratio :0.6
# Doing experiment 363!
# Done (0h 4m and 45.88s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 2 ratio :0.15
# Doing experiment 369!
# Done (0h 5m and 17.66s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 2 ratio :0.3
# Doing experiment 373!
# Done (0h 4m and 57.52s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 2 ratio :0.6
# Doing experiment 378!
# Done (0h 5m and 4.36s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 3 ratio :0.15
# Doing experiment 383!
# Done (0h 5m and 5.26s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 3 ratio :0.3
# Doing experiment 388!
# Done (0h 4m and 52.84s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 3 ratio :0.6
# Doing experiment 394!
# Done (0h 5m and 17.11s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 4 ratio :[0, 0.25]
# Doing experiment 398!
# Done (0h 5m and 0.43s).
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 400!
# Done (0h 5m and 0.93s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 5 ratio :[0, 0.25]
# Doing experiment 111!
# Done (0h 5m and 7.11s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 5 ratio :[0.1, 0.3]
# Doing experiment 116!
# Done (0h 4m and 48.17s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 1 ratio :0.15
# Doing experiment 120!
# Done (0h 5m and 16.88s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 1 ratio :0.3
# Doing experiment 124!
# Done (0h 5m and 0.64s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 1 ratio :0.6
# Doing experiment 129!
# Done (0h 4m and 59.64s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 2 ratio :0.15
# Doing experiment 134!
# Done (0h 5m and 8.34s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 2 ratio :0.3
# Doing experiment 138!
# Done (0h 4m and 59.85s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 2 ratio :0.6
# Doing experiment 142!
# Done (0h 5m and 10.96s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 3 ratio :0.15
# Doing experiment 147!
# Done (0h 5m and 2.94s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 3 ratio :0.3
# Doing experiment 149!
# Done (0h 4m and 43.69s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 3 ratio :0.6
# Doing experiment 150!
# Done (0h 5m and 13.78s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 4 ratio :[0, 0.25]
# Doing experiment 151!
# Done (0h 4m and 50.04s).
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 4 ratio :[0.1, 0.3]
# Doing experiment 152!
# Done (0h 4m and 52.90s).
#
# Done (2h 10m and 59.84s).

# %%
df
# Out:
#     dataset_name  experiment_number             approach missing_data_handling            imputation_method use_missing_indicator_variables num_samples  imbalance_ratio  missingness_pattern missingness_mechanism ratio_of_missing_values missing_X1 missing_X2 missing_first_quarter ratio_missing_per_class_0 ratio_missing_per_class_1      auc  Accuracy       F1      MCC  Sensitivity  Specificity  Precision     PPV      NPV      FNR     FDR      FOR resolution  bandwidth  estimation_time_0  estimation_time_1
# 0          moons                135  multi_distributions               without                      without                            None       10000             0.50                    1                  MCAR                     0.2       True      False                  None                       NaN                       NaN      NaN   0.37700  0.37200 -0.24600      0.37800      0.37600     0.3660  0.3660  0.38800  0.62200  0.6340  0.61200         30        0.2                NaN                NaN
# 1          moons                 61  multi_distributions               without                      without                            None        5000             0.25                    4                  MNAR                    None       True       True                 False                         0                    0.9404      NaN   0.44200  0.49800  0.27500      1.00000      0.22800     0.3320  0.3320  1.00000  0.00000  0.6680  0.00000         30        0.2                NaN                NaN
# 2          moons                 95                  nam              encoding                         None                           False       10000             0.10                    1                  MCAR                     0.6       True      False                  None                       NaN                       NaN  0.94630   0.96445  0.78650  0.78985      0.64930      0.99995     0.9996  0.9996  0.96200  0.35070  0.0004  0.03800         30        0.2                NaN                NaN
# 3          moons                132  multi_distributions               without                      without                            None       10000             0.25                    5                  MNAR                    None       True       True                  True                  0.169733                    0.0786      NaN   0.29600  0.12400 -0.40100      0.21100      0.32200     0.0880  0.0880  0.56800  0.78900  0.9120  0.43200         30        0.2                NaN                NaN
# 4          moons                 59  multi_distributions               without                      without                            None        5000             0.25                    3                   MAR                  0.2084       True      False                  True                      None                      None      NaN   0.22400  0.14200 -0.48200      0.25700      0.21300     0.0980  0.0980  0.46400  0.74300  0.9020  0.53600         30        0.2                NaN                NaN
# ..           ...                ...                  ...                   ...                          ...                             ...         ...              ...                  ...                   ...                     ...        ...        ...                   ...                       ...                       ...      ...       ...      ...      ...          ...          ...        ...     ...      ...      ...     ...      ...        ...        ...                ...                ...
# 562      circles                171                  nam              encoding                         None                           False        5000             0.25                    1                  MCAR                       0       True      False                  None                       NaN                       NaN  1.00000   0.96855  0.93235  0.91590      0.87415      1.00000     1.0000  1.0000  0.96000  0.12585  0.0000  0.04000         30        0.2                NaN                NaN
# 563      circles                343                  nam              encoding                         None                           False       10000             0.10                    5                  MNAR                    None       True       True                  True                         0                    0.2285  0.98605   0.92120  0.37565  0.46095      0.23195      1.00000     1.0000  1.0000  0.91935  0.76805  0.0000  0.08065         30        0.2                NaN                NaN
# 564      circles                185  single_distribution            imputation                          knn                             NaN        5000             0.50                    5                  MNAR                    None       True       True                  True                         0                    0.2378      NaN   0.99900  0.99900  0.99800      0.99800      1.00000     1.0000  1.0000  0.99800  0.00200  0.0000  0.00200         30        0.2                NaN                NaN
# 565      circles                 25  single_distribution            imputation  multi_dimensional_weighting                             NaN        5000             0.25                    4                  MNAR                    None       True       True                 False                    0.6528                    0.9724      NaN   0.63800  0.59800  0.44500      0.97100      0.51000     0.4320  0.4320  0.97900  0.02900  0.5680  0.02100         30        0.2                NaN                NaN
# 566      circles                388                  nam              encoding                         None                           False       10000             0.10                    3                   MAR                  0.2437       True      False                  True                      None                      None  0.97010   0.90025  0.00000      NaN      0.00000      1.00000        NaN     NaN  0.90025  1.00000     NaN  0.10010         30        0.2                NaN                NaN
#
# [567 rows x 32 columns]

# %%
#Dataset default parameters
num_samples = 10000#NUM_SAMPLES

# pdf estimation default parameters
resolution = RESOLUTION
bandwidth = BANDWIDTH

# Classification default parameters
proportion_train = PROPORTION_TRAIN

# Verbosity
verbosity=0


"""  Parameters of the experiment """



range_dataset_name = ['circles', 'moons']
range_use_missing_indicator_variables = [True]
range_missing_data_handling = ['imputing'] #TODO THIS IS WHERE WE SHOULD DO IMUTING BASED ON THE  OTHER EXPERIMENT


range_ratio_of_missing_values = [0, .1, 0.3]
range_ratio_missing_per_class = [[0,0.25], [0.1, 0.3]]
range_imbalance_ratio = [0.1, 0.25, 0.5]
range_missingness_pattern = [5, 1, 2, 3, 4]
approach = 'nam'
imputation_method='mice'

df = create_df()

# %%
"""  Fix parameters """

#Dataset default parameters
num_samples = 8000#NUM_SAMPLES

# pdf estimation default parameters
resolution = RESOLUTION
bandwidth = BANDWIDTH

# Classification default parameters
proportion_train = PROPORTION_TRAIN

# Verbosity
verbosity=0


"""  Parameters of the experiment """



range_dataset_name = ['circles', 'moons']
range_use_missing_indicator_variables = [False]
range_missing_data_handling = ['imputing'] #TODO THIS IS WHERE WE SHOULD DO IMUTING BASED ON THE  OTHER EXPERIMENT


range_ratio_of_missing_values = [.15, .3, 0.6]
range_ratio_missing_per_class = [[0,0.25], [0.1, 0.3]]
range_imbalance_ratio = [0.1]
range_missingness_pattern = [5, 1, 2, 3, 4,]
approach = 'nam'
imputation_method='mice'

df = create_df()
print("Approach is Neural Additive Model with encoding of the missing values with or without the indicator variables!\n\n\n")
start_total_time = time()

for dataset_name in range_dataset_name:
    for missing_data_handling in range_missing_data_handling:
        for use_missing_indicator_variables in range_use_missing_indicator_variables:
            for imbalance_ratio in range_imbalance_ratio:
                for missingness_pattern in range_missingness_pattern:

                    if missingness_pattern in [1, 2, 3]:
                        for ratio_of_missing_values in range_ratio_of_missing_values:
                            if len(df.query( " `dataset_name`==@dataset_name & `approach` == @approach & `use_missing_indicator_variables`==@use_missing_indicator_variables & `imputation_method` == @imputation_method & `missing_data_handling` == @missing_data_handling & `ratio_of_missing_values`==@ratio_of_missing_values & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :
                                continue

                            try:
                                #if not len(df.query( " `dataset_name`==@dataset_name & `ratio_of_missing_values`==@ratio_of_missing_values & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :

                                print("{} - use_missing_indicator_variables: {} imbalance: {} pattern: {} ratio :{}".format(dataset_name, 
                                                                                                                                  use_missing_indicator_variables, 
                                                                                                                                  imbalance_ratio,
                                                                                                                                  missingness_pattern,
                                                                                                                                  ratio_of_missing_values))

                                start_time = time()

                                dataset = DatasetGenerator(dataset_name=dataset_name, 
                                                        num_samples=num_samples, 
                                                        imbalance_ratio=imbalance_ratio, 
                                                        missing_data_handling=missing_data_handling,
                                                        imputation_method=imputation_method,
                                                        verbosity=verbosity)

                                # Creation of the missingness
                                dataset.generate_missing_coordinates(missingness_pattern=missingness_pattern, ratio_of_missing_values=ratio_of_missing_values, ratio_missing_per_class=None)

                                dataset.split_test_train()

                                # Change dataset missing data handling
                                dataset.change_imputation_approach(missing_data_handling=missing_data_handling, imputation_method=imputation_method)

                                # Create the experiments
                                exp = Experiments(dataset_name, 
                                                  dataset=dataset, 
                                                  purpose='classification', 
                                                  approach = approach, 
                                                  previous_experiment=None, 
                                                  save_experiment=True, 
                                                  verbosity=verbosity, 
                                                  debug=False, 
                                                  proportion_train=PROPORTION_TRAIN, 
                                                  resolution=RESOLUTION, 
                                                  bandwidth=BANDWIDTH,
                                                  random_state=RANDOM_STATE)


                                # Estimate the distributions 
                                exp.fit(use_missing_indicator_variables=use_missing_indicator_variables)

                                # Estimate the distributions 
                                exp.predict()

                                end_time = time()

                                hours, rest = divmod(end_time - start_time, 3600)
                                minutes, seconds = divmod(rest, 60)
                                print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
                            except:
                                print("/!\. Error!\n")

                    elif missingness_pattern in [4, 5]:
                        for ratio_missing_per_class in range_ratio_missing_per_class:
                            if len(df.query( " `dataset_name`==@dataset_name & `approach` == @approach & `use_missing_indicator_variables`==@use_missing_indicator_variables & `imputation_method` == @imputation_method & `missing_data_handling` == @missing_data_handling & `ratio_missing_per_class_0`==@ratio_missing_per_class[0] & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :
                                continue




                            try:
                                #if not len(df.query( " `dataset_name`==@dataset_name & `ratio_of_missing_values`==@ratio_of_missing_values & `imbalance_ratio`==@imbalance_ratio & `missingness_pattern`==@missingness_pattern")) >= 1 :

                                print("{} - use_missing_indicator_variables: {} imbalance: {} pattern: {} ratio :{}".format(dataset_name, 
                                                                                                                                  use_missing_indicator_variables, 
                                                                                                                                  imbalance_ratio,
                                                                                                                                  missingness_pattern,
                                                                                                                                  str(ratio_missing_per_class)))

                                start_time = time()

                                dataset = DatasetGenerator(dataset_name=dataset_name, 
                                                        num_samples=num_samples, 
                                                        imbalance_ratio=imbalance_ratio, 
                                                        missing_data_handling=missing_data_handling,
                                                        imputation_method=imputation_method,
                                                        verbosity=verbosity)

                                # Creation of the missingness
                                dataset.generate_missing_coordinates(missingness_pattern=missingness_pattern, ratio_of_missing_values=None, ratio_missing_per_class=ratio_missing_per_class)

                                dataset.split_test_train()

                                # Create the experiments
                                exp = Experiments(dataset_name, 
                                                  dataset=dataset, 
                                                  purpose='classification', 
                                                  approach = approach, 
                                                  previous_experiment=None, 
                                                  save_experiment=True, 
                                                  verbosity=verbosity, 
                                                  debug=False, 
                                                  proportion_train=PROPORTION_TRAIN, 
                                                  resolution=RESOLUTION, 
                                                  bandwidth=BANDWIDTH,
                                                  random_state=RANDOM_STATE)


                                # Estimate the distributions 
                                exp.fit(use_missing_indicator_variables=use_missing_indicator_variables)

                                # Estimate the distributions 
                                exp.predict()


                                end_time = time()

                                hours, rest = divmod(end_time - start_time, 3600)
                                minutes, seconds = divmod(rest, 60)
                                print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
                            except:
                                print("/!\. Error!\n")

end_total_time = time()

hours, rest = divmod(end_total_time - start_total_time, 3600)
minutes, seconds = divmod(rest, 60)
print("Done ({}h {}m and {:.2f}s).\n".format(int(hours), int(minutes), seconds))
# Out:
# Approach is Neural Additive Model with encoding of the missing values with or without the indicator variables!
#
#
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 5 ratio :[0, 0.25]
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 5 ratio :[0.1, 0.3]
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 1 ratio :0.15
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 1 ratio :0.3
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 1 ratio :0.6
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 2 ratio :0.15
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 2 ratio :0.3
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 2 ratio :0.6
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 3 ratio :0.15
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 3 ratio :0.3
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 3 ratio :0.6
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 4 ratio :[0, 0.25]
# /!\. Error!
#
# circles - use_missing_indicator_variables: False imbalance: 0.1 pattern: 4 ratio :[0.1, 0.3]
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 5 ratio :[0, 0.25]
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 5 ratio :[0.1, 0.3]
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 1 ratio :0.15
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 1 ratio :0.3
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 1 ratio :0.6
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 2 ratio :0.15
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 2 ratio :0.3
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 2 ratio :0.6
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 3 ratio :0.15
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 3 ratio :0.3
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 3 ratio :0.6
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 4 ratio :[0, 0.25]
# /!\. Error!
#
# moons - use_missing_indicator_variables: False imbalance: 0.1 pattern: 4 ratio :[0.1, 0.3]
# /!\. Error!
#
# Done (0h 0m and 16.07s).
